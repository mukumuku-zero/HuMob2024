# %%
import os
import random
import numpy as np
import torch
import tensorflow as tf
from transformers.trainer_utils import set_seed

def set_random_seed(seed: int = 42):
    # Python, NumPy, random モジュール、PyTorch のシードを設定
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    
    # TensorFlow のシードを設定
    tf.random.set_seed(seed)

    # PyTorch 設定（再現性のためにcudnnの設定を固定）
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_random_seed(42)

# %%
import torch
import tensorflow as tf
import gc

def report_memory():
    """
    PyTorchおよびTensorFlowのGPUメモリ使用量を報告する関数
    """
    if torch.cuda.is_available():
        pass
    else:
        print("PyTorchでGPUが検出されませんでした。")

    # TensorFlowのメモリ使用量報告
    # print("\nTensorFlowのメモリ使用量:")
    gpu_devices = tf.config.experimental.list_physical_devices('GPU')
    if gpu_devices:
        for i, gpu in enumerate(gpu_devices):
            details = tf.config.experimental.get_memory_info(f"GPU:{i}")
    else:
        print("TensorFlowでGPUが検出されませんでした。")

def cleanup_gpu_memory():
    """
    PyTorchおよびTensorFlowのGPUメモリをクリーンアップし、メモリ使用量を報告する関数
    """
    # ガベージコレクション
    gc.collect()

    # PyTorchのメモリクリーンアップ
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        torch.cuda.reset_peak_memory_stats()
        torch.cuda.reset_accumulated_memory_stats()

    # TensorFlowのメモリクリーンアップ
    tf.keras.backend.clear_session()
    gpu_devices = tf.config.experimental.list_physical_devices('GPU')
    if gpu_devices:
        for i, gpu in enumerate(gpu_devices):
            tf.config.experimental.reset_memory_stats(f"GPU:{i}")  # デバイス名を "GPU:0" の形式で指定

    # print("After cleanup:")
    report_memory()

# %%
import torch.nn as nn
import torch_geometric.nn as pyg_nn
import torch.nn.functional as F
from torch_geometric.utils import degree

class Swish(nn.Module):
    def forward(self, x):
        return x * torch.sigmoid(x)
        
class STGCNModel(nn.Module):
    def __init__(self, in_channels, hidden_channels, num_classes):
        super(STGCNModel, self).__init__()

        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        self.conv1 = pyg_nn.ChebConv(in_channels, hidden_channels, K=3)  # Kは多項式の次数
        self.conv2 = pyg_nn.ChebConv(hidden_channels, hidden_channels, K=3)
        
        # 時系列を扱うLSTM (bidirectional=Trueの時、出力は2倍のhidden_channelsになるため、全結合層の入力も2倍にする)
        self.lstm = nn.LSTM(hidden_channels, hidden_channels, batch_first=True)
        self.swish = Swish()
        self.fc = nn.Linear(hidden_channels, num_classes)
    
    def forward(self, data): 
        # グラフ畳み込み層の適用
        x, edge_index = data.x.to(self.device), data.edge_index.to(self.device)
        x = self.conv1(x, edge_index)
        x = self.swish(x)
        x = self.conv2(x, edge_index)
        
        # LSTM
        x = x.unsqueeze(1)  # 時系列次元を追加
        x, (h_n, c_n) = self.lstm(x)

        embedding = x[:, -1, :]

        # 出力層
        x = self.fc(embedding)  # 最後のタイムステップの出力を取得

        return x, embedding

# %%
def featurecreation(data):

    print('start create feature...')
    
    # 曜日をsin, cosを用いて表現する特徴量を追加
    data['d_sin'] = np.sin(2 * np.pi * data['d'] / 7)
    data['d_cos'] = np.cos(2 * np.pi * data['d'] / 7)

    # 時間をsin, cosを用いて表現する特徴量を追加
    data['t_sin'] = np.sin(2 * np.pi * data['t'] / 48)
    data['t_cos'] = np.cos(2 * np.pi * data['t'] / 48)

    data['time_point'] = data['t'].apply(lambda x: 0 if (0 <= x <= 14) else (0 if (38 <= x <= 48) else 1)) # 0-7時と19-24時

    return data

# %%
def create_edge_index(data):
    num_nodes = len(data)
    edge_index = torch.tensor([
        [i for i in range(num_nodes - 1)],  # エッジの始点
        [i + 1 for i in range(num_nodes - 1)]  # エッジの終点
    ], dtype=torch.long)
    return edge_index

# %%
# トレーニングプロセス
def train_model(data, labels, model, optimizer, criterion, thresholds, epochs=300, patience=10):
    results = []
    
    model.train()
    set_random_seed(42)
    best_loss = float('inf')
    patience_counter = 0
    best_model_state = None  # ベストモデルの状態を保存する変数

    for epoch in range(epochs):
        optimizer.zero_grad()
        out, _ = model(data)
        loss = criterion(out, labels)  # x座標とy座標の予測

        if epoch==0:
            results.append({
                'epoch': epoch,
                'loss': loss.item()
            })

        if (epoch==0)&(loss.item() >= thresholds):
            best_model_state = None
            return results, best_model_state, loss
        
        loss.backward()
        optimizer.step()
        
        # エポックごとにベスト損失を記録
        if loss.item() < best_loss:
            best_loss = loss.item()
            patience_counter = 0  # 改善が見られたのでリセット
            best_model_state = model.state_dict()  # モデルの状態を保存
        else:
            patience_counter += 1  # 改善が見られなかった場合、カウンターを増やす

        # 100単位で損失を表示
        if epoch % 100 == 0:
            print(f'Epoch {epoch}, Loss: {loss.item()}')
            
        # アーリーストッピング条件
        if patience_counter >= patience:
            print(f"Early stopping at epoch {epoch} with best loss {best_loss:.4f}")
            break

    # ベストモデルの状態に戻す
    if best_model_state is not None:
        model.load_state_dict(best_model_state)  # メモリ上でベストモデルを復元
        print(f"Best model restored with loss {best_loss:.4f}")

    return results, best_model_state, loss

def add_embedding_to_dataframe(df, embedding):
    embedding_np = embedding.cpu().numpy()
    embedding_df = pd.DataFrame(embedding_np, columns=[f'dim_{i}' for i in range(embedding_np.shape[1])])
    data = pd.concat([df['x_y'].reset_index(drop=True), embedding_df], axis=1)
    return data

# 重みの初期化関数
def initialize_weights(m):
    set_random_seed(42)
    if isinstance(m, nn.Linear):  # 線形層の場合
        torch.nn.init.xavier_uniform_(m.weight)  # Xavier一様分布で重みを初期化
        if m.bias is not None:
            m.bias.data.fill_(0.0)  # バイアスを0で初期化

# %%
import torch
from torch_geometric.data import Data
import torch_geometric.transforms as T
from sklearn.preprocessing import LabelEncoder
import geobleu_main.geobleu as geobleu
import time
import itertools
import csv
from sklearn.svm import SVR, SVC
import pandas as pd
import numpy as np
from tensorflow import keras
import geobleu_main.geobleu as geobleu
import warnings
from sklearn.preprocessing import MinMaxScaler, StandardScaler 

warnings.filterwarnings("ignore")

def create_data(df_target, thresholds, save_dir, city_name):

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    # 特徴量エンジニアリング
    print(df_target.shape)
    df = featurecreation(df_target)
    print(df.shape)

    df['x_y'] = df['x'].astype(str) + '_' + df['y'].astype(str)
    
    # データをuidごとにグループ化
    grouped_data = df.groupby('uid')
    
    generated_all = []
    
    start = time.perf_counter()
    
    for uid, group in grouped_data:
        print(f"Processing uid: {uid}")

        group = group.reset_index(drop=True)

        if len(group[group['d']<60].x_y.unique())==1:
            x = group[group['d']<60].x.unique()
            y = group[group['d']<60].y.unique()
            cnt=0
            for index, row in group[group['d']>=60].iterrows():
                d = row['d']
                t = row['t']

                if cnt == 0:
                    print(x[0], y[0])
                    cnt+=1

                # データを整形してリストに追加
                generated_all.append((uid, d, t, x[0], y[0]))  # avg_xとavg_yを取得する際に[0]を指定して値を取り出す

        else:
            train_data = group[group['d'] < 60]
            test_data = group[group['d'] >= 60]
        
            # 学習用と評価用の edge_index を作成
            train_edge_index = create_edge_index(train_data)
            test_edge_index = create_edge_index(test_data)
        
            use_col = ['d_sin', 'd_cos', 't_sin', 't_cos', 'time_point']
        
            # ノード特徴量を準備
            train_x = torch.tensor(train_data[use_col].values, dtype=torch.float)
            test_x = torch.tensor(test_data[use_col].values, dtype=torch.float)
        
            # データセット作成
            data_tr = Data(x=train_x, edge_index=train_edge_index)
            data_ts = Data(x=test_x, edge_index=test_edge_index)
        
            # x_yラベルを数値に変換
            label_encoder = LabelEncoder()
            train_data['x_y_encoded'] = label_encoder.fit_transform(train_data['x_y'])
            
            # エンコーディングされたラベルをPyTorchテンソルに変換
            labels = torch.tensor(train_data['x_y_encoded'].values, dtype=torch.long)
            
            # モデル、損失関数、オプティマイザの設定
            num_classes = len(train_data['x_y'].unique())  # クラス数
            model = STGCNModel(in_channels=len(use_col), hidden_channels=64, num_classes=num_classes)
    
            # 重みの初期化を適用
            model.apply(initialize_weights)
            
            criterion = nn.CrossEntropyLoss()  # クラス分類なのでCrossEntropyを使用
            optimizer = torch.optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)
            
            # モデルをGPUに移動
            model = model.to(device)
            
            # データもGPUに移動
            data_tr = data_tr.to(device)
            
            labels = labels.to(device)
            results, best_model_state, loss = train_model(data_tr, labels, model, optimizer, criterion, thresholds, epochs=500, patience=15)
        
            del train_x, train_edge_index, labels, model
            cleanup_gpu_memory()
    
            if loss >= thresholds:
                model = SVC(kernel='rbf', random_state=42)
                X = train_data[use_col]
                y = train_data['x_y']
                model.fit(X, y)
                predictions = []
                
                for _, test_row in test_data.iterrows():
                    test_row_values = test_row[use_col].astype(float).values  # 値をNumPy配列に変換
                    predicted_x_y = model.predict(test_row_values.reshape(1, -1))
                    
                    # 予測結果をリストに追加
                    predictions.append(predicted_x_y[0])
            else:
                model = STGCNModel(in_channels=len(use_col), hidden_channels=64, num_classes=num_classes)
                model = model.to(device)
                model.load_state_dict(best_model_state)
                
                # 予測
                model.eval()
                
                data_ts = data_ts.to(device)
                with torch.no_grad():
                    # ベストモデルでtrain/testエンベディングを取得
                    _, train_embedding = model(data_tr)
                    _, test_embedding = model(data_ts)
            
                train_svc = add_embedding_to_dataframe(train_data, train_embedding)
                test_svc = add_embedding_to_dataframe(test_data, test_embedding)
                test_svc = test_svc.drop('x_y', axis=1)
            
                model_svc = SVC(kernel='rbf', random_state=42)
                X = train_svc.drop('x_y', axis=1)
                y = train_svc['x_y']
                
                model_svc.fit(X, y)
    
                predictions = []
                
                for _, test_row in test_svc.iterrows():
                    test_row_values = test_row.astype(float).values  # 値をNumPy配列に変換
                    predicted_x_y = model_svc.predict(test_row_values.reshape(1, -1))
                    
                    # 予測結果をリストに追加
                    predictions.append(predicted_x_y[0])
                    
            predicted_x_y = np.array(predictions)
        
            del model, data_ts, test_x, test_edge_index
            cleanup_gpu_memory()
                
            predictions = np.array([pred.split('_') for pred in predicted_x_y])
            
            # 予測されたxとyをそれぞれ整数に変換
            avg_x = predictions[:, 0].astype(float).astype(int)
            avg_y = predictions[:, 1].astype(float).astype(int)
            
            # xとyの値を四捨五入して整数値に変換
            avg_x = np.where(avg_x < 1, 1, np.where(avg_x > 200, 200, avg_x.round().astype(int)))
            avg_y = np.where(avg_y < 1, 1, np.where(avg_y > 200, 200, avg_y.round().astype(int)))
        
        
            # d, t, x, y列を持つ空のデータフレームを作成
            columns = ['uid', 'd', 't', 'x', 'y']
            df_pr = pd.DataFrame(columns=columns)
            
            df_pr['uid'], df_pr['d'], df_pr['t'], df_pr['x'], df_pr['y'] = test_data['uid'], test_data['d'], test_data['t'], avg_x, avg_y
        
            # (d, t, x, y)のタプルのリストを作成
            generated = [tuple(row) for row in df_pr[['uid', 'd', 't', 'x', 'y']].to_numpy()]
            generated_all.extend(generated)

    df_generated = pd.DataFrame(generated_all, columns=['uid', 'd', 't', 'x', 'y'])

    filename = f"{save_dir}/mukumuku_city{city_name}_humob24.csv"

    # gzip形式で保存
    df_generated.to_csv(f'{filename}.gz', index=False, compression="gzip")

    # csv形式で保存
    df_generated.to_csv(filename, index=False)

    print("ファイル保存完了")
    
    end = time.perf_counter()
    print('{:.2f}分'.format((end-start)/60))

# %%
import os

# ⇒上記の結果から閾値を以下のように設定
# cityB: 5.1
# cityC: 5.2
# cityD: 5.3

city_list = ['B', 'C', 'D']
thresholds_list = [5.1, 5.2, 5.3]
save_dir = 'submit_file_GNN'

if not os.path.exists(save_dir):
    os.makedirs(save_dir)
    
for i, c in enumerate(city_list):

    thresholds = thresholds_list[i]

    print(f'City Name: city{c}')
    print(f'Threshold: {thresholds}')

    df_target = pd.read_csv(f'HuMob_Data/city{c}_challengedata_target.csv')

    # # Test
    # first_10_uids = df_target['uid'].unique()[:100]
    
    # # それに対応するデータを抽出
    # test = df_target[df_target['uid'].isin(first_10_uids)]
    
    create_data(df_target, thresholds, save_dir, c)
# Out:
# City Name: cityB
# Threshold: 5.1
# (2399892, 5)
# start create feature...
# (2399892, 10)
# Processing uid: 22000
# Epoch 0, Loss: 3.8010895252227783
# Epoch 100, Loss: 1.6108635663986206
# Epoch 200, Loss: 1.0982691049575806
# Epoch 300, Loss: 0.7103473544120789
# Epoch 400, Loss: 0.48730239272117615
# Best model restored with loss 0.3662
# Processing uid: 22001
# Epoch 0, Loss: 4.438796520233154
# Epoch 100, Loss: 2.092865228652954
# Epoch 200, Loss: 1.7626616954803467
# Epoch 300, Loss: 1.4297770261764526
# Epoch 400, Loss: 1.1591169834136963
# Best model restored with loss 0.9635
# Processing uid: 22002
# Epoch 0, Loss: 4.941259384155273
# Epoch 100, Loss: 2.957155227661133
# Epoch 200, Loss: 2.268467664718628
# Epoch 300, Loss: 1.8036857843399048
# Epoch 400, Loss: 1.5228379964828491
# Best model restored with loss 1.3416
# Processing uid: 22003
# Epoch 0, Loss: 3.5065600872039795
# Epoch 100, Loss: 1.2708261013031006
# Epoch 200, Loss: 1.1212379932403564
# Epoch 300, Loss: 0.9522225260734558
# Epoch 400, Loss: 0.7780984044075012
# Best model restored with loss 0.6231
# Processing uid: 22004
# Epoch 0, Loss: 4.694629192352295
# Epoch 100, Loss: 1.991228699684143
# Epoch 200, Loss: 1.6627589464187622
# Epoch 300, Loss: 1.3875294923782349
# Epoch 400, Loss: 1.1428868770599365
# Best model restored with loss 0.9434
# Processing uid: 22005
# Epoch 0, Loss: 5.038863658905029
# Epoch 100, Loss: 2.612248182296753
# Epoch 200, Loss: 1.455327033996582
# Epoch 300, Loss: 0.8809478878974915
# Epoch 400, Loss: 0.6108589172363281
# Best model restored with loss 0.4686
# Processing uid: 22006
# Epoch 0, Loss: 4.346748352050781
# Epoch 100, Loss: 2.6458637714385986
# Epoch 200, Loss: 1.8141887187957764
# Epoch 300, Loss: 1.1632715463638306
# Epoch 400, Loss: 0.8003945350646973
# Best model restored with loss 0.5897
# Processing uid: 22007
# Epoch 0, Loss: 4.817841053009033
# Epoch 100, Loss: 2.993112087249756
# Epoch 200, Loss: 2.2886722087860107
# Epoch 300, Loss: 1.9117131233215332
# Epoch 400, Loss: 1.6935323476791382
# Best model restored with loss 1.5547
# Processing uid: 22008
# Epoch 0, Loss: 4.2873711585998535
# Epoch 100, Loss: 2.2440943717956543
# Epoch 200, Loss: 1.4207712411880493
# Epoch 300, Loss: 0.9253115057945251
# Epoch 400, Loss: 0.6602169275283813
# Best model restored with loss 0.5097
# Processing uid: 22009
# Epoch 0, Loss: 4.589983940124512
# Epoch 100, Loss: 2.344087839126587
# Epoch 200, Loss: 1.2707312107086182
# Epoch 300, Loss: 0.7005850672721863
# Epoch 400, Loss: 0.44518667459487915
# Best model restored with loss 0.3134
# Processing uid: 22010
# Epoch 0, Loss: 4.319518089294434
# Epoch 100, Loss: 2.4021658897399902
# Epoch 200, Loss: 1.2914644479751587
# Epoch 300, Loss: 0.7268244624137878
# Epoch 400, Loss: 0.4701138436794281
# Best model restored with loss 0.3381
# Processing uid: 22011
# Epoch 0, Loss: 4.5668511390686035
# Epoch 100, Loss: 2.641373872756958
# Epoch 200, Loss: 1.801928162574768
# Epoch 300, Loss: 1.1192920207977295
# Epoch 400, Loss: 0.7370020151138306
# Best model restored with loss 0.5299
# Processing uid: 22012
# Epoch 0, Loss: 5.017473220825195
# Epoch 100, Loss: 2.816420316696167
# Epoch 200, Loss: 1.6443692445755005
# Epoch 300, Loss: 1.0005487203598022
# Epoch 400, Loss: 0.6820883750915527
# Best model restored with loss 0.5101
# Processing uid: 22013
# Epoch 0, Loss: 5.009504795074463
# Epoch 100, Loss: 2.6455676555633545
# Epoch 200, Loss: 1.3063457012176514
# Epoch 300, Loss: 0.7323635816574097
# Epoch 400, Loss: 0.47202321887016296
# Best model restored with loss 0.3345
# Processing uid: 22014
# Processing uid: 22015
# Epoch 0, Loss: 4.9772257804870605
# Epoch 100, Loss: 3.0645854473114014
# Epoch 200, Loss: 2.1342804431915283
# Epoch 300, Loss: 1.521120309829712
# Epoch 400, Loss: 1.1377869844436646
# Best model restored with loss 0.8993
# Processing uid: 22016
# Epoch 0, Loss: 4.362155437469482
# Epoch 100, Loss: 2.508146286010742
# Epoch 200, Loss: 1.5740681886672974
# Epoch 300, Loss: 1.0553244352340698
# Epoch 400, Loss: 0.771949827671051
# Best model restored with loss 0.6017
# Processing uid: 22017
# Epoch 0, Loss: 3.944882869720459
# Epoch 100, Loss: 1.4686236381530762
# Epoch 200, Loss: 0.48492705821990967
# Epoch 300, Loss: 0.2089056819677353
# Epoch 400, Loss: 0.12643758952617645
# Best model restored with loss 0.0925
# Processing uid: 22018
# Epoch 0, Loss: 4.49543571472168
# Epoch 100, Loss: 1.770374059677124
# Epoch 200, Loss: 1.511141061782837
# Epoch 300, Loss: 1.275412917137146
# Epoch 400, Loss: 1.0598702430725098
# Best model restored with loss 0.8749
# Processing uid: 22019
# Epoch 0, Loss: 4.276494026184082
# Epoch 100, Loss: 2.46844482421875
# Epoch 200, Loss: 1.5580297708511353
# Epoch 300, Loss: 0.9820818901062012
# Epoch 400, Loss: 0.6870819330215454
# Best model restored with loss 0.5234
# Processing uid: 22020
# Epoch 0, Loss: 4.218429088592529
# Epoch 100, Loss: 2.042990207672119
# Epoch 200, Loss: 1.3281662464141846
# Epoch 300, Loss: 0.7698230743408203
# Epoch 400, Loss: 0.4689177870750427
# Best model restored with loss 0.3109
# Processing uid: 22021
# Epoch 0, Loss: 4.6821393966674805
# Epoch 100, Loss: 2.180704116821289
# Epoch 200, Loss: 1.9289573431015015
# Epoch 300, Loss: 1.6594682931900024
# Epoch 400, Loss: 1.4031270742416382
# Best model restored with loss 1.1816
# Processing uid: 22022
# Epoch 0, Loss: 4.785911560058594
# Epoch 100, Loss: 2.8823859691619873
# Epoch 200, Loss: 2.0556533336639404
# Epoch 300, Loss: 1.4916877746582031
# Epoch 400, Loss: 1.1336174011230469
# Best model restored with loss 0.9046
# Processing uid: 22023
# Epoch 0, Loss: 4.5681538581848145
# Epoch 100, Loss: 2.543799638748169
# Epoch 200, Loss: 2.2459256649017334
# Epoch 300, Loss: 1.9330607652664185
# Epoch 400, Loss: 1.6575675010681152
# Best model restored with loss 1.4448
# Processing uid: 22024
# Epoch 0, Loss: 4.838656902313232
# Epoch 100, Loss: 2.905968189239502
# Epoch 200, Loss: 2.200820207595825
# Epoch 300, Loss: 1.6902178525924683
# Epoch 400, Loss: 1.3543082475662231
# Best model restored with loss 1.1267
# Processing uid: 22025
# Processing uid: 22026
# Epoch 0, Loss: 4.9660234451293945
# Epoch 100, Loss: 3.1721274852752686
# Epoch 200, Loss: 2.5057713985443115
# Epoch 300, Loss: 1.9511417150497437
# Epoch 400, Loss: 1.5475425720214844
# Best model restored with loss 1.2701
# Processing uid: 22027
# Processing uid: 22028
# Epoch 0, Loss: 5.029890060424805
# Epoch 100, Loss: 2.6176023483276367
# Epoch 200, Loss: 1.23568856716156
# Epoch 300, Loss: 0.7083373665809631
# Epoch 400, Loss: 0.4772574305534363
# Best model restored with loss 0.3525
# Processing uid: 22029
# Processing uid: 22030
# Epoch 0, Loss: 4.934548854827881
# Epoch 100, Loss: 3.020862579345703
# Epoch 200, Loss: 2.0361177921295166
# Epoch 300, Loss: 1.3529661893844604
# Epoch 400, Loss: 0.9801661372184753
# Best model restored with loss 0.7608
# Processing uid: 22031
# Epoch 0, Loss: 4.7935967445373535
# Epoch 100, Loss: 2.8972184658050537
# Epoch 200, Loss: 1.8381154537200928
# Epoch 300, Loss: 1.250751256942749
# Epoch 400, Loss: 0.9242913126945496
# Best model restored with loss 0.7266
# Processing uid: 22032
# Epoch 0, Loss: 4.006485939025879
# Epoch 100, Loss: 1.7699894905090332
# Epoch 200, Loss: 1.3300533294677734
# Epoch 300, Loss: 0.9891420006752014
# Epoch 400, Loss: 0.7799585461616516
# Best model restored with loss 0.6442
# Processing uid: 22033
# Epoch 0, Loss: 4.131472110748291
# Epoch 100, Loss: 2.0524020195007324
# Epoch 200, Loss: 1.1388018131256104
# Epoch 300, Loss: 0.6729856133460999
# Epoch 400, Loss: 0.4488641321659088
# Best model restored with loss 0.3214
# Processing uid: 22034
# Epoch 0, Loss: 4.6817522048950195
# Epoch 100, Loss: 2.0964386463165283
# Epoch 200, Loss: 0.8897608518600464
# Epoch 300, Loss: 0.5043988823890686
# Epoch 400, Loss: 0.34871840476989746
# Best model restored with loss 0.2649
# Processing uid: 22035
# Epoch 0, Loss: 4.0434417724609375
# Epoch 100, Loss: 1.7864220142364502
# Epoch 200, Loss: 1.385945439338684
# Epoch 300, Loss: 1.021207332611084
# Epoch 400, Loss: 0.7642582058906555
# Best model restored with loss 0.5956
# Processing uid: 22036
# Processing uid: 22037
# Epoch 0, Loss: 3.9151673316955566
# Epoch 100, Loss: 0.9571324586868286
# Epoch 200, Loss: 0.9168225526809692
# Epoch 300, Loss: 0.8675501942634583
# Epoch 400, Loss: 0.8074101209640503
# Best model restored with loss 0.7394
# Processing uid: 22038
# Epoch 0, Loss: 4.711397171020508
# Epoch 100, Loss: 2.598710536956787
# Epoch 200, Loss: 1.5275293588638306
# Epoch 300, Loss: 0.8403477072715759
# Epoch 400, Loss: 0.5140277147293091
# Best model restored with loss 0.3526
# Processing uid: 22039
# Epoch 0, Loss: 4.611194133758545
# Epoch 100, Loss: 1.9767111539840698
# Epoch 200, Loss: 1.4152191877365112
# Epoch 300, Loss: 0.9724918007850647
# Epoch 400, Loss: 0.6960859298706055
# Best model restored with loss 0.5363
# Processing uid: 22040
# Epoch 0, Loss: 4.860485553741455
# Epoch 100, Loss: 3.1168971061706543
# Epoch 200, Loss: 2.075709581375122
# Epoch 300, Loss: 1.432140588760376
# Epoch 400, Loss: 1.0644056797027588
# Best model restored with loss 0.8418
# Processing uid: 22041
# Processing uid: 22042
# Epoch 0, Loss: 4.284681797027588
# Epoch 100, Loss: 1.921515941619873
# Epoch 200, Loss: 1.768989086151123
# Epoch 300, Loss: 1.6212084293365479
# Epoch 400, Loss: 1.4700746536254883
# Best model restored with loss 1.3210
# Processing uid: 22043
# Processing uid: 22044
# Processing uid: 22045
# Epoch 0, Loss: 4.604880332946777
# Epoch 100, Loss: 2.174631118774414
# Epoch 200, Loss: 1.6880555152893066
# Epoch 300, Loss: 1.3592703342437744
# Epoch 400, Loss: 1.1377694606781006
# Best model restored with loss 0.9794
# Processing uid: 22046
# Epoch 0, Loss: 5.047601222991943
# Epoch 100, Loss: 2.922020435333252
# Epoch 200, Loss: 1.9090524911880493
# Epoch 300, Loss: 1.312511920928955
# Epoch 400, Loss: 0.9736307859420776
# Best model restored with loss 0.7691
# Processing uid: 22047
# Epoch 0, Loss: 4.762452125549316
# Epoch 100, Loss: 2.5890517234802246
# Epoch 200, Loss: 1.4600718021392822
# Epoch 300, Loss: 0.8517642617225647
# Epoch 400, Loss: 0.5668907165527344
# Best model restored with loss 0.4159
# Processing uid: 22048
# Epoch 0, Loss: 4.428140163421631
# Epoch 100, Loss: 2.463466167449951
# Epoch 200, Loss: 1.7708302736282349
# Epoch 300, Loss: 1.2272002696990967
# Epoch 400, Loss: 0.8893454670906067
# Best model restored with loss 0.6861
# Processing uid: 22049
# Processing uid: 22050
# Epoch 0, Loss: 4.062711238861084
# Epoch 100, Loss: 2.012159585952759
# Epoch 200, Loss: 1.1872831583023071
# Epoch 300, Loss: 0.7159594297409058
# Epoch 400, Loss: 0.4843404293060303
# Best model restored with loss 0.3592
# Processing uid: 22051
# Processing uid: 22052
# Epoch 0, Loss: 4.24387264251709
# Epoch 100, Loss: 2.128160238265991
# Epoch 200, Loss: 0.9741979241371155
# Epoch 300, Loss: 0.4621553421020508
# Epoch 400, Loss: 0.2812986969947815
# Best model restored with loss 0.1966
# Processing uid: 22053
# Epoch 0, Loss: 5.006067752838135
# Epoch 100, Loss: 2.4408392906188965
# Epoch 200, Loss: 2.213287830352783
# Epoch 300, Loss: 1.998259425163269
# Epoch 400, Loss: 1.8048425912857056
# Best model restored with loss 1.6388
# Processing uid: 22054
# Epoch 0, Loss: 4.59640645980835
# Epoch 100, Loss: 2.6392433643341064
# Epoch 200, Loss: 1.3590296506881714
# Epoch 300, Loss: 0.7089241743087769
# Epoch 400, Loss: 0.4249609410762787
# Best model restored with loss 0.2880
# Processing uid: 22055
# Epoch 0, Loss: 4.608892440795898
# Epoch 100, Loss: 2.277848720550537
# Epoch 200, Loss: 1.6347464323043823
# Epoch 300, Loss: 1.1366809606552124
# Epoch 400, Loss: 0.8430647253990173
# Best model restored with loss 0.6685
# Processing uid: 22056
# Epoch 0, Loss: 4.638392448425293
# Epoch 100, Loss: 2.6213438510894775
# Epoch 200, Loss: 1.9226232767105103
# Epoch 300, Loss: 1.4248048067092896
# Epoch 400, Loss: 1.0921931266784668
# Best model restored with loss 0.8735
# Processing uid: 22057
# Epoch 0, Loss: 4.970920562744141
# Epoch 100, Loss: 2.6500959396362305
# Epoch 200, Loss: 1.4567229747772217
# Epoch 300, Loss: 0.8920150995254517
# Epoch 400, Loss: 0.6245337724685669
# Best model restored with loss 0.4758
# Processing uid: 22058
# Processing uid: 22059
# Processing uid: 22060
# Epoch 0, Loss: 4.434988498687744
# Epoch 100, Loss: 2.200812339782715
# Epoch 200, Loss: 1.8222167491912842
# Epoch 300, Loss: 1.3821971416473389
# Epoch 400, Loss: 1.044182538986206
# Best model restored with loss 0.7997
# Processing uid: 22061
# Epoch 0, Loss: 4.984809398651123
# Epoch 100, Loss: 2.805636167526245
# Epoch 200, Loss: 1.5662965774536133
# Epoch 300, Loss: 0.9828039407730103
# Epoch 400, Loss: 0.6898792386054993
# Best model restored with loss 0.5161
# Processing uid: 22062
# Epoch 0, Loss: 4.7978315353393555
# Epoch 100, Loss: 2.656895399093628
# Epoch 200, Loss: 1.4561198949813843
# Epoch 300, Loss: 0.8061686754226685
# Epoch 400, Loss: 0.5041635632514954
# Best model restored with loss 0.3494
# Processing uid: 22063
# Epoch 0, Loss: 4.807799816131592
# Epoch 100, Loss: 2.4833672046661377
# Epoch 200, Loss: 2.118257761001587
# Epoch 300, Loss: 1.768082618713379
# Epoch 400, Loss: 1.454380750656128
# Best model restored with loss 1.2139
# Processing uid: 22064
# Processing uid: 22065
# Epoch 0, Loss: 4.578738212585449
# Epoch 100, Loss: 2.2624588012695312
# Epoch 200, Loss: 0.9866539835929871
# Epoch 300, Loss: 0.5033671259880066
# Epoch 400, Loss: 0.3072037398815155
# Best model restored with loss 0.2097
# Processing uid: 22066
# Processing uid: 22067
# Epoch 0, Loss: 4.309895038604736
# Epoch 100, Loss: 1.7454960346221924
# Epoch 200, Loss: 1.4097633361816406
# Epoch 300, Loss: 1.1101558208465576
# Epoch 400, Loss: 0.8627899885177612
# Best model restored with loss 0.6912
# Processing uid: 22068
# Epoch 0, Loss: 4.691972255706787
# Epoch 100, Loss: 2.387056827545166
# Epoch 200, Loss: 2.0530447959899902
# Epoch 300, Loss: 1.7300183773040771
# Epoch 400, Loss: 1.4470252990722656
# Best model restored with loss 1.2067
# Processing uid: 22069
# Epoch 0, Loss: 5.002196311950684
# Epoch 100, Loss: 3.012652635574341
# Epoch 200, Loss: 1.9698078632354736
# Epoch 300, Loss: 1.3308438062667847
# Epoch 400, Loss: 0.9785451889038086
# Best model restored with loss 0.7736
# Processing uid: 22070
# Epoch 0, Loss: 4.4223737716674805
# Epoch 100, Loss: 2.1939821243286133
# Epoch 200, Loss: 1.5507136583328247
# Epoch 300, Loss: 0.9921814799308777
# Epoch 400, Loss: 0.642662525177002
# Best model restored with loss 0.4424
# Processing uid: 22071
# Epoch 0, Loss: 4.824914455413818
# Epoch 100, Loss: 2.3066015243530273
# Epoch 200, Loss: 1.1049304008483887
# Epoch 300, Loss: 0.6127289533615112
# Epoch 400, Loss: 0.4013565182685852
# Best model restored with loss 0.2884
# Processing uid: 22072
# Epoch 0, Loss: 5.021188259124756
# Epoch 100, Loss: 2.8815762996673584
# Epoch 200, Loss: 2.4521701335906982
# Epoch 300, Loss: 2.119204521179199
# Epoch 400, Loss: 1.8551729917526245
# Best model restored with loss 1.6620
# Processing uid: 22073
# Processing uid: 22074
# Processing uid: 22075
# Processing uid: 22076
# Processing uid: 22077
# Epoch 0, Loss: 4.642446994781494
# Epoch 100, Loss: 2.058830976486206
# Epoch 200, Loss: 0.754291296005249
# Epoch 300, Loss: 0.3543684780597687
# Epoch 400, Loss: 0.2049332559108734
# Best model restored with loss 0.1347
# Processing uid: 22078
# Processing uid: 22079
# Epoch 0, Loss: 4.3932294845581055
# Epoch 100, Loss: 2.178746461868286
# Epoch 200, Loss: 1.8937197923660278
# Epoch 300, Loss: 1.5998284816741943
# Epoch 400, Loss: 1.3175801038742065
# Best model restored with loss 1.0796
# Processing uid: 22080
# Epoch 0, Loss: 4.85567045211792
# Epoch 100, Loss: 3.2710413932800293
# Epoch 200, Loss: 2.2963743209838867
# Epoch 300, Loss: 1.6691555976867676
# Epoch 400, Loss: 1.2996187210083008
# Best model restored with loss 1.0611
# Processing uid: 22081
# 79 90
# Processing uid: 22082
# Epoch 0, Loss: 4.673234939575195
# Epoch 100, Loss: 2.569948673248291
# Epoch 200, Loss: 1.383952260017395
# Epoch 300, Loss: 0.7488685846328735
# Epoch 400, Loss: 0.46385690569877625
# Best model restored with loss 0.3214
# Processing uid: 22083
# Epoch 0, Loss: 4.963065147399902
# Epoch 100, Loss: 3.110682487487793
# Epoch 200, Loss: 2.234877586364746
# Epoch 300, Loss: 1.6565930843353271
# Epoch 400, Loss: 1.2928084135055542
# Best model restored with loss 1.0557
# Processing uid: 22084
# Epoch 0, Loss: 4.910479545593262
# Epoch 100, Loss: 3.0521209239959717
# Epoch 200, Loss: 2.2151072025299072
# Epoch 300, Loss: 1.6159313917160034
# Epoch 400, Loss: 1.229015588760376
# Best model restored with loss 0.9860
# Processing uid: 22085
# Epoch 0, Loss: 4.864178657531738
# Epoch 100, Loss: 2.7155590057373047
# Epoch 200, Loss: 1.4891870021820068
# Epoch 300, Loss: 0.9169588685035706
# Epoch 400, Loss: 0.6471609473228455
# Best model restored with loss 0.4969
# Processing uid: 22086
# Epoch 0, Loss: 4.8245930671691895
# Epoch 100, Loss: 2.5214083194732666
# Epoch 200, Loss: 1.3909986019134521
# Epoch 300, Loss: 0.7627732753753662
# Epoch 400, Loss: 0.4650030732154846
# Best model restored with loss 0.3214
# Processing uid: 22087
# Epoch 0, Loss: 4.31140661239624
# Epoch 100, Loss: 2.5445871353149414
# Epoch 200, Loss: 1.823513150215149
# Epoch 300, Loss: 1.2754260301589966
# Epoch 400, Loss: 0.9595282077789307
# Best model restored with loss 0.7717
# Processing uid: 22088
# Epoch 0, Loss: 4.198183059692383
# Epoch 100, Loss: 2.4629180431365967
# Epoch 200, Loss: 1.4506453275680542
# Epoch 300, Loss: 0.8272680044174194
# Epoch 400, Loss: 0.5275028944015503
# Best model restored with loss 0.3727
# Processing uid: 22089
# Epoch 0, Loss: 4.813295364379883
# Epoch 100, Loss: 2.564282178878784
# Epoch 200, Loss: 1.4239429235458374
# Epoch 300, Loss: 0.9089750051498413
# Epoch 400, Loss: 0.6534128785133362
# Best model restored with loss 0.5054
# Processing uid: 22090
# Processing uid: 22091
# Epoch 0, Loss: 4.704076766967773
# Epoch 100, Loss: 2.6626129150390625
# Epoch 200, Loss: 1.588997721672058
# Epoch 300, Loss: 0.9315863847732544
# Epoch 400, Loss: 0.6217062473297119
# Best model restored with loss 0.4549
# Processing uid: 22092
# Epoch 0, Loss: 4.01168966293335
# Epoch 100, Loss: 1.6701470613479614
# Epoch 200, Loss: 0.6387304067611694
# Epoch 300, Loss: 0.29615262150764465
# Epoch 400, Loss: 0.17534175515174866
# Best model restored with loss 0.1174
# Processing uid: 22093
# Epoch 0, Loss: 4.559438228607178
# Epoch 100, Loss: 2.357614517211914
# Epoch 200, Loss: 1.7385978698730469
# Epoch 300, Loss: 1.2016956806182861
# Epoch 400, Loss: 0.8459033370018005
# Best model restored with loss 0.6359
# Processing uid: 22094
# Epoch 0, Loss: 4.223320007324219
# Epoch 100, Loss: 2.167126417160034
# Epoch 200, Loss: 1.4825997352600098
# Epoch 300, Loss: 0.9815974831581116
# Epoch 400, Loss: 0.6961509585380554
# Best model restored with loss 0.5348
# Processing uid: 22095
# Epoch 0, Loss: 4.176294326782227
# Epoch 100, Loss: 1.5645966529846191
# Epoch 200, Loss: 1.3227399587631226
# Epoch 300, Loss: 1.038645625114441
# Epoch 400, Loss: 0.8033083081245422
# Best model restored with loss 0.6352
# Processing uid: 22096
# Epoch 0, Loss: 4.255183696746826
# Epoch 100, Loss: 2.250153064727783
# Epoch 200, Loss: 1.9877499341964722
# Epoch 300, Loss: 1.6775529384613037
# Epoch 400, Loss: 1.3815371990203857
# Best model restored with loss 1.1635
# Processing uid: 22097
# Epoch 0, Loss: 4.746400356292725
# Epoch 100, Loss: 2.531121015548706
# Epoch 200, Loss: 1.9465689659118652
# Epoch 300, Loss: 1.4947724342346191
# Epoch 400, Loss: 1.1923152208328247
# Best model restored with loss 0.9883
# Processing uid: 22098
# Epoch 0, Loss: 4.477275371551514
# Epoch 100, Loss: 2.5557069778442383
# Epoch 200, Loss: 1.9310824871063232
# Epoch 300, Loss: 1.3404910564422607
# Epoch 400, Loss: 0.9350209832191467
# Best model restored with loss 0.6916
# Processing uid: 22099
# Epoch 0, Loss: 4.971938610076904
# Epoch 100, Loss: 2.7145962715148926
# Epoch 200, Loss: 1.3657392263412476
# Epoch 300, Loss: 0.7714660167694092
# Epoch 400, Loss: 0.5116423964500427
# Best model restored with loss 0.3745
# Processing uid: 22100
# Epoch 0, Loss: 4.819836139678955
# Epoch 100, Loss: 2.3976967334747314
# Epoch 200, Loss: 1.2743310928344727
# Epoch 300, Loss: 0.7509194016456604
# Epoch 400, Loss: 0.5108761787414551
# Best model restored with loss 0.3873
# Processing uid: 22101
# Epoch 0, Loss: 4.93647575378418
# Epoch 100, Loss: 2.363133430480957
# Epoch 200, Loss: 1.871964454650879
# Epoch 300, Loss: 1.4487720727920532
# Epoch 400, Loss: 1.1203309297561646
# Best model restored with loss 0.8824
# Processing uid: 22102
# Epoch 0, Loss: 4.270072937011719
# Epoch 100, Loss: 1.9258646965026855
# Epoch 200, Loss: 0.9168837666511536
# Epoch 300, Loss: 0.46004799008369446
# Epoch 400, Loss: 0.27683889865875244
# Best model restored with loss 0.1879
# Processing uid: 22103
# Epoch 0, Loss: 4.985560417175293
# Epoch 100, Loss: 3.1363627910614014
# Epoch 200, Loss: 2.2024669647216797
# Epoch 300, Loss: 1.5836637020111084
# Epoch 400, Loss: 1.2137733697891235
# Best model restored with loss 0.9828
# Processing uid: 22104
# Epoch 0, Loss: 4.8942975997924805
# Epoch 100, Loss: 2.726452350616455
# Epoch 200, Loss: 1.956465721130371
# Epoch 300, Loss: 1.4580788612365723
# Epoch 400, Loss: 1.1426875591278076
# Best model restored with loss 0.9450
# Processing uid: 22105
# Epoch 0, Loss: 4.8100504875183105
# Epoch 100, Loss: 2.6479601860046387
# Epoch 200, Loss: 1.811432123184204
# Epoch 300, Loss: 1.328209400177002
# Epoch 400, Loss: 1.0395164489746094
# Best model restored with loss 0.8613
# Processing uid: 22106
# Epoch 0, Loss: 4.89564847946167
# Epoch 100, Loss: 2.4142496585845947
# Epoch 200, Loss: 2.0005433559417725
# Epoch 300, Loss: 1.6056187152862549
# Epoch 400, Loss: 1.2756922245025635
# Best model restored with loss 1.0299
# Processing uid: 22107
# Processing uid: 22108
# Epoch 0, Loss: 4.3882904052734375
# Epoch 100, Loss: 2.435821533203125
# Epoch 200, Loss: 1.1557254791259766
# Epoch 300, Loss: 0.6059929132461548
# Epoch 400, Loss: 0.3799145221710205
# Best model restored with loss 0.2660
# Processing uid: 22109
# Processing uid: 22110
# Processing uid: 22111
# Epoch 0, Loss: 4.544731140136719
# Epoch 100, Loss: 2.466766119003296
# Epoch 200, Loss: 1.916778802871704
# Epoch 300, Loss: 1.3927333354949951
# Epoch 400, Loss: 1.022878646850586
# Best model restored with loss 0.7955
# Processing uid: 22112
# Epoch 0, Loss: 4.785670280456543
# Epoch 100, Loss: 2.3795549869537354
# Epoch 200, Loss: 1.9303607940673828
# Epoch 300, Loss: 1.5912235975265503
# Epoch 400, Loss: 1.3460850715637207
# Best model restored with loss 1.1764
# Processing uid: 22113
# Epoch 0, Loss: 4.970529079437256
# Epoch 100, Loss: 2.8458092212677
# Epoch 200, Loss: 1.9399774074554443
# Epoch 300, Loss: 1.345969319343567
# Epoch 400, Loss: 0.9951598644256592
# Best model restored with loss 0.7763
# Processing uid: 22114
# Epoch 0, Loss: 4.4427571296691895
# Epoch 100, Loss: 1.9185229539871216
# Epoch 200, Loss: 0.7533715963363647
# Epoch 300, Loss: 0.3882749676704407
# Epoch 400, Loss: 0.24245280027389526
# Best model restored with loss 0.1717
# Processing uid: 22115
# Processing uid: 22116
# Epoch 0, Loss: 4.427277565002441
# Epoch 100, Loss: 2.5078649520874023
# Epoch 200, Loss: 1.4834258556365967
# Epoch 300, Loss: 0.9173797965049744
# Epoch 400, Loss: 0.6390509009361267
# Best model restored with loss 0.4886
# Processing uid: 22117
# Epoch 0, Loss: 4.537173271179199
# Epoch 100, Loss: 2.59895920753479
# Epoch 200, Loss: 1.9204555749893188
# Epoch 300, Loss: 1.4074902534484863
# Epoch 400, Loss: 1.0614365339279175
# Best model restored with loss 0.8389
# Processing uid: 22118
# Epoch 0, Loss: 4.16845703125
# Epoch 100, Loss: 1.8760170936584473
# Epoch 200, Loss: 1.4209508895874023
# Epoch 300, Loss: 1.0091583728790283
# Epoch 400, Loss: 0.7327024340629578
# Best model restored with loss 0.5629
# Processing uid: 22119
# Epoch 0, Loss: 4.831909656524658
# Epoch 100, Loss: 2.721064805984497
# Epoch 200, Loss: 1.819606900215149
# Epoch 300, Loss: 1.256546974182129
# Epoch 400, Loss: 0.9089758396148682
# Best model restored with loss 0.6977
# Processing uid: 22120
# Epoch 0, Loss: 4.703657627105713
# Epoch 100, Loss: 2.9656338691711426
# Epoch 200, Loss: 2.1363608837127686
# Epoch 300, Loss: 1.5218942165374756
# Epoch 400, Loss: 1.1358530521392822
# Best model restored with loss 0.9083
# Processing uid: 22121
# Epoch 0, Loss: 4.76175594329834
# Epoch 100, Loss: 2.585416555404663
# Epoch 200, Loss: 1.8407845497131348
# Epoch 300, Loss: 1.330597996711731
# Epoch 400, Loss: 1.0109416246414185
# Best model restored with loss 0.8156
# Processing uid: 22122
# Processing uid: 22123
# Epoch 0, Loss: 4.143702030181885
# Epoch 100, Loss: 2.2025704383850098
# Epoch 200, Loss: 1.8086942434310913
# Epoch 300, Loss: 1.4133023023605347
# Epoch 400, Loss: 1.1046478748321533
# Best model restored with loss 0.8925
# Processing uid: 22124
# Epoch 0, Loss: 4.587367057800293
# Epoch 100, Loss: 2.2417116165161133
# Epoch 200, Loss: 1.6499706506729126
# Epoch 300, Loss: 1.146789312362671
# Epoch 400, Loss: 0.8272340297698975
# Best model restored with loss 0.6285
# Processing uid: 22125
# Epoch 0, Loss: 4.224368095397949
# Epoch 100, Loss: 2.353752613067627
# Epoch 200, Loss: 1.5382771492004395
# Epoch 300, Loss: 0.9513158798217773
# Epoch 400, Loss: 0.6076619029045105
# Best model restored with loss 0.4220
# Processing uid: 22126
# Epoch 0, Loss: 4.690243244171143
# Epoch 100, Loss: 2.7736849784851074
# Epoch 200, Loss: 1.9001801013946533
# Epoch 300, Loss: 1.3621363639831543
# Epoch 400, Loss: 1.0743076801300049
# Best model restored with loss 0.9054
# Processing uid: 22127
# Epoch 0, Loss: 4.1148271560668945
# Epoch 100, Loss: 1.5535889863967896
# Epoch 200, Loss: 1.1659495830535889
# Epoch 300, Loss: 0.871441125869751
# Epoch 400, Loss: 0.6710178852081299
# Best model restored with loss 0.5408
# Processing uid: 22128
# Processing uid: 22129
# Epoch 0, Loss: 4.782593727111816
# Epoch 100, Loss: 2.1901955604553223
# Epoch 200, Loss: 1.5441808700561523
# Epoch 300, Loss: 1.1179531812667847
# Epoch 400, Loss: 0.8455619812011719
# Best model restored with loss 0.6742
# Processing uid: 22130
# Epoch 0, Loss: 4.62916374206543
# Epoch 100, Loss: 2.4826531410217285
# Epoch 200, Loss: 1.2657952308654785
# Epoch 300, Loss: 0.6968210935592651
# Epoch 400, Loss: 0.45386481285095215
# Best model restored with loss 0.3313
# Processing uid: 22131
# Epoch 0, Loss: 4.839962959289551
# Epoch 100, Loss: 2.4201207160949707
# Epoch 200, Loss: 1.8850603103637695
# Epoch 300, Loss: 1.4567649364471436
# Epoch 400, Loss: 1.1443781852722168
# Best model restored with loss 0.9370
# Processing uid: 22132
# Epoch 0, Loss: 4.613304138183594
# Epoch 100, Loss: 2.5311994552612305
# Epoch 200, Loss: 2.1235511302948
# Epoch 300, Loss: 1.771242618560791
# Epoch 400, Loss: 1.473690152168274
# Best model restored with loss 1.2513
# Processing uid: 22133
# Epoch 0, Loss: 3.4558937549591064
# Epoch 100, Loss: 1.5219093561172485
# Epoch 200, Loss: 1.1008714437484741
# Epoch 300, Loss: 0.7077247500419617
# Epoch 400, Loss: 0.4608343839645386
# Best model restored with loss 0.3229
# Processing uid: 22134
# Epoch 0, Loss: 4.676179885864258
# Epoch 100, Loss: 2.322172164916992
# Epoch 200, Loss: 1.4259973764419556
# Epoch 300, Loss: 0.8440131545066833
# Epoch 400, Loss: 0.5465870499610901
# Best model restored with loss 0.3947
# Processing uid: 22135
# Epoch 0, Loss: 4.02219295501709
# Epoch 100, Loss: 2.176558017730713
# Epoch 200, Loss: 1.5528488159179688
# Epoch 300, Loss: 1.0521644353866577
# Epoch 400, Loss: 0.739130437374115
# Best model restored with loss 0.5532
# Processing uid: 22136
# Epoch 0, Loss: 3.941174268722534
# Epoch 100, Loss: 2.171645164489746
# Epoch 200, Loss: 1.6660891771316528
# Epoch 300, Loss: 1.299727439880371
# Epoch 400, Loss: 1.0552231073379517
# Best model restored with loss 0.9070
# Processing uid: 22137
# Epoch 0, Loss: 4.213133335113525
# Epoch 100, Loss: 1.7620638608932495
# Epoch 200, Loss: 1.3650298118591309
# Epoch 300, Loss: 1.0549776554107666
# Epoch 400, Loss: 0.8047201633453369
# Best model restored with loss 0.6227
# Processing uid: 22138
# Processing uid: 22139
# Epoch 0, Loss: 3.4482500553131104
# Epoch 100, Loss: 2.0028719902038574
# Epoch 200, Loss: 1.4866269826889038
# Epoch 300, Loss: 1.049497365951538
# Epoch 400, Loss: 0.7870672345161438
# Best model restored with loss 0.6260
# Processing uid: 22140
# Epoch 0, Loss: 4.579990863800049
# Epoch 100, Loss: 2.244917631149292
# Epoch 200, Loss: 1.6221650838851929
# Epoch 300, Loss: 1.1304751634597778
# Epoch 400, Loss: 0.8128101229667664
# Best model restored with loss 0.6177
# Processing uid: 22141
# Epoch 0, Loss: 3.511289358139038
# Epoch 100, Loss: 1.867524266242981
# Epoch 200, Loss: 1.5432310104370117
# Epoch 300, Loss: 1.2838622331619263
# Epoch 400, Loss: 1.0907254219055176
# Best model restored with loss 0.9533
# Processing uid: 22142
# Epoch 0, Loss: 4.537212371826172
# Epoch 100, Loss: 2.634373188018799
# Epoch 200, Loss: 2.019280195236206
# Epoch 300, Loss: 1.5804704427719116
# Epoch 400, Loss: 1.2866597175598145
# Best model restored with loss 1.0908
# Processing uid: 22143
# Processing uid: 22144
# Epoch 0, Loss: 4.4507951736450195
# Epoch 100, Loss: 2.5264506340026855
# Epoch 200, Loss: 2.1460680961608887
# Epoch 300, Loss: 1.7233465909957886
# Epoch 400, Loss: 1.3691346645355225
# Best model restored with loss 1.1232
# Processing uid: 22145
# Epoch 0, Loss: 4.751237392425537
# Epoch 100, Loss: 2.84830641746521
# Epoch 200, Loss: 2.3640172481536865
# Epoch 300, Loss: 1.9052510261535645
# Epoch 400, Loss: 1.5152292251586914
# Best model restored with loss 1.2358
# Processing uid: 22146
# Epoch 0, Loss: 4.596248626708984
# Epoch 100, Loss: 2.4884002208709717
# Epoch 200, Loss: 1.5961711406707764
# Epoch 300, Loss: 0.9602017402648926
# Epoch 400, Loss: 0.6111703515052795
# Best model restored with loss 0.4344
# Processing uid: 22147
# Epoch 0, Loss: 4.977020263671875
# Epoch 100, Loss: 2.8771586418151855
# Epoch 200, Loss: 1.9228463172912598
# Epoch 300, Loss: 1.3242051601409912
# Epoch 400, Loss: 0.9708961844444275
# Best model restored with loss 0.7590
# Processing uid: 22148
# Epoch 0, Loss: 4.7168707847595215
# Epoch 100, Loss: 2.526158571243286
# Epoch 200, Loss: 1.9804718494415283
# Epoch 300, Loss: 1.5129960775375366
# Epoch 400, Loss: 1.1801449060440063
# Best model restored with loss 0.9546
# Processing uid: 22149
# Processing uid: 22150
# Epoch 0, Loss: 4.2850871086120605
# Epoch 100, Loss: 2.320751905441284
# Epoch 200, Loss: 1.7036805152893066
# Epoch 300, Loss: 1.1585971117019653
# Epoch 400, Loss: 0.7897545695304871
# Best model restored with loss 0.5802
# Processing uid: 22151
# Epoch 0, Loss: 4.23064661026001
# Epoch 100, Loss: 2.4765851497650146
# Epoch 200, Loss: 1.947913646697998
# Epoch 300, Loss: 1.4712716341018677
# Epoch 400, Loss: 1.149523377418518
# Best model restored with loss 0.9532
# Processing uid: 22152
# Epoch 0, Loss: 4.786382675170898
# Epoch 100, Loss: 2.956746816635132
# Epoch 200, Loss: 2.0496625900268555
# Epoch 300, Loss: 1.4040191173553467
# Epoch 400, Loss: 1.0099135637283325
# Best model restored with loss 0.7756
# Processing uid: 22153
# Epoch 0, Loss: 4.784194469451904
# Epoch 100, Loss: 2.3496222496032715
# Epoch 200, Loss: 2.1034021377563477
# Epoch 300, Loss: 1.8197271823883057
# Epoch 400, Loss: 1.5560779571533203
# Best model restored with loss 1.3389
# Processing uid: 22154
# Epoch 0, Loss: 4.965964317321777
# Epoch 100, Loss: 2.804185390472412
# Epoch 200, Loss: 2.011404037475586
# Epoch 300, Loss: 1.4032316207885742
# Epoch 400, Loss: 1.0042856931686401
# Best model restored with loss 0.7730
# Processing uid: 22155
# Processing uid: 22156
# Epoch 0, Loss: 4.481815814971924
# Epoch 100, Loss: 1.9543665647506714
# Epoch 200, Loss: 1.6303315162658691
# Epoch 300, Loss: 1.3542078733444214
# Epoch 400, Loss: 1.1071652173995972
# Best model restored with loss 0.9027
# Processing uid: 22157
# Epoch 0, Loss: 4.440062522888184
# Epoch 100, Loss: 2.5962870121002197
# Epoch 200, Loss: 2.097166061401367
# Epoch 300, Loss: 1.6409962177276611
# Epoch 400, Loss: 1.2826207876205444
# Best model restored with loss 1.0364
# Processing uid: 22158
# Epoch 0, Loss: 5.037965297698975
# Epoch 100, Loss: 3.3426263332366943
# Epoch 200, Loss: 2.6213552951812744
# Epoch 300, Loss: 2.076052665710449
# Epoch 400, Loss: 1.702756643295288
# Best model restored with loss 1.4566
# Processing uid: 22159
# Epoch 0, Loss: 5.064578056335449
# Epoch 100, Loss: 3.2169289588928223
# Epoch 200, Loss: 2.0296146869659424
# Epoch 300, Loss: 1.3635978698730469
# Epoch 400, Loss: 1.003930926322937
# Best model restored with loss 0.7847
# Processing uid: 22160
# Epoch 0, Loss: 4.179481029510498
# Epoch 100, Loss: 2.636413097381592
# Epoch 200, Loss: 1.8699957132339478
# Epoch 300, Loss: 1.3687653541564941
# Epoch 400, Loss: 1.094710350036621
# Best model restored with loss 0.9370
# Processing uid: 22161
# Epoch 0, Loss: 3.6635336875915527
# Epoch 100, Loss: 1.7128632068634033
# Epoch 200, Loss: 1.1121973991394043
# Epoch 300, Loss: 0.6924447417259216
# Epoch 400, Loss: 0.4575711190700531
# Best model restored with loss 0.3261
# Processing uid: 22162
# Epoch 0, Loss: 4.526954174041748
# Epoch 100, Loss: 2.250927686691284
# Epoch 200, Loss: 1.2503464221954346
# Epoch 300, Loss: 0.6814176440238953
# Epoch 400, Loss: 0.4243040978908539
# Best model restored with loss 0.2969
# Processing uid: 22163
# Epoch 0, Loss: 4.318276882171631
# Epoch 100, Loss: 2.1641173362731934
# Epoch 200, Loss: 1.62047278881073
# Epoch 300, Loss: 1.1561752557754517
# Epoch 400, Loss: 0.8527480959892273
# Best model restored with loss 0.6719
# Processing uid: 22164
# Epoch 0, Loss: 4.324786186218262
# Epoch 100, Loss: 2.4505157470703125
# Epoch 200, Loss: 1.7518773078918457
# Epoch 300, Loss: 1.247167944908142
# Epoch 400, Loss: 0.9434860348701477
# Best model restored with loss 0.7599
# Processing uid: 22165
# Epoch 0, Loss: 5.058923721313477
# Epoch 100, Loss: 3.088150978088379
# Epoch 200, Loss: 2.3222813606262207
# Epoch 300, Loss: 1.7866815328598022
# Epoch 400, Loss: 1.429666519165039
# Best model restored with loss 1.1907
# Processing uid: 22166
# Epoch 0, Loss: 4.767098426818848
# Epoch 100, Loss: 2.7599661350250244
# Epoch 200, Loss: 1.6330429315567017
# Epoch 300, Loss: 1.0290814638137817
# Epoch 400, Loss: 0.7139776945114136
# Best model restored with loss 0.5352
# Processing uid: 22167
# Epoch 0, Loss: 4.641560077667236
# Epoch 100, Loss: 2.319563150405884
# Epoch 200, Loss: 1.4275245666503906
# Epoch 300, Loss: 0.8627575039863586
# Epoch 400, Loss: 0.5706285834312439
# Best model restored with loss 0.4143
# Processing uid: 22168
# Epoch 0, Loss: 4.68944787979126
# Epoch 100, Loss: 2.8585145473480225
# Epoch 200, Loss: 1.8096420764923096
# Epoch 300, Loss: 1.1936384439468384
# Epoch 400, Loss: 0.8817513585090637
# Best model restored with loss 0.7086
# Processing uid: 22169
# Epoch 0, Loss: 4.249865531921387
# Epoch 100, Loss: 2.217714548110962
# Epoch 200, Loss: 1.0795987844467163
# Epoch 300, Loss: 0.5626972317695618
# Epoch 400, Loss: 0.34767869114875793
# Best model restored with loss 0.2407
# Processing uid: 22170
# Epoch 0, Loss: 4.500907897949219
# Epoch 100, Loss: 2.0763323307037354
# Epoch 200, Loss: 1.123340368270874
# Epoch 300, Loss: 0.712847888469696
# Epoch 400, Loss: 0.5051513910293579
# Best model restored with loss 0.3927
# Processing uid: 22171
# Epoch 0, Loss: 4.241079330444336
# Epoch 100, Loss: 2.194416046142578
# Epoch 200, Loss: 1.5196257829666138
# Epoch 300, Loss: 1.010970115661621
# Epoch 400, Loss: 0.6981598734855652
# Best model restored with loss 0.5211
# Processing uid: 22172
# Epoch 0, Loss: 3.5928821563720703
# Epoch 100, Loss: 1.0948388576507568
# Epoch 200, Loss: 0.9495455622673035
# Epoch 300, Loss: 0.7994967699050903
# Epoch 400, Loss: 0.6498724818229675
# Best model restored with loss 0.5205
# Processing uid: 22173
# Processing uid: 22174
# Processing uid: 22175
# Epoch 0, Loss: 4.877101898193359
# Epoch 100, Loss: 2.670253038406372
# Epoch 200, Loss: 1.5506420135498047
# Epoch 300, Loss: 0.9866585731506348
# Epoch 400, Loss: 0.6984176635742188
# Best model restored with loss 0.5343
# Processing uid: 22176
# Processing uid: 22177
# Epoch 0, Loss: 4.580370903015137
# Epoch 100, Loss: 2.540531635284424
# Epoch 200, Loss: 1.7423129081726074
# Epoch 300, Loss: 1.1907974481582642
# Epoch 400, Loss: 0.8698594570159912
# Best model restored with loss 0.6765
# Processing uid: 22178
# Processing uid: 22179
# Epoch 0, Loss: 4.505239963531494
# Epoch 100, Loss: 2.282651901245117
# Epoch 200, Loss: 1.2337086200714111
# Epoch 300, Loss: 0.6850513219833374
# Epoch 400, Loss: 0.43029287457466125
# Best model restored with loss 0.3000
# Processing uid: 22180
# Epoch 0, Loss: 4.753023624420166
# Epoch 100, Loss: 2.8012993335723877
# Epoch 200, Loss: 1.9927136898040771
# Epoch 300, Loss: 1.4041173458099365
# Epoch 400, Loss: 1.0341038703918457
# Best model restored with loss 0.8037
# Processing uid: 22181
# Epoch 0, Loss: 5.0787153244018555
# Epoch 100, Loss: 2.832895040512085
# Epoch 200, Loss: 2.000088691711426
# Epoch 300, Loss: 1.4705184698104858
# Epoch 400, Loss: 1.1624337434768677
# Best model restored with loss 0.9754
# Processing uid: 22182
# Epoch 0, Loss: 4.551743030548096
# Epoch 100, Loss: 2.0984749794006348
# Epoch 200, Loss: 1.7699190378189087
# Epoch 300, Loss: 1.4959818124771118
# Epoch 400, Loss: 1.2538697719573975
# Best model restored with loss 1.0638
# Processing uid: 22183
# Epoch 0, Loss: 4.816730499267578
# Epoch 100, Loss: 2.230351686477661
# Epoch 200, Loss: 1.6356992721557617
# Epoch 300, Loss: 1.1419882774353027
# Epoch 400, Loss: 0.8047038912773132
# Best model restored with loss 0.5980
# Processing uid: 22184
# Epoch 0, Loss: 4.217907428741455
# Epoch 100, Loss: 1.6369603872299194
# Epoch 200, Loss: 1.1823863983154297
# Epoch 300, Loss: 0.7575312852859497
# Epoch 400, Loss: 0.48724526166915894
# Best model restored with loss 0.3338
# Processing uid: 22185
# Epoch 0, Loss: 4.860105037689209
# Epoch 100, Loss: 2.4724225997924805
# Epoch 200, Loss: 1.92783784866333
# Epoch 300, Loss: 1.4427287578582764
# Epoch 400, Loss: 1.079912543296814
# Best model restored with loss 0.8326
# Processing uid: 22186
# Processing uid: 22187
# Epoch 0, Loss: 4.902759552001953
# Epoch 100, Loss: 2.7846145629882812
# Epoch 200, Loss: 1.9060786962509155
# Epoch 300, Loss: 1.333103895187378
# Epoch 400, Loss: 0.9880403280258179
# Best model restored with loss 0.7768
# Processing uid: 22188
# Processing uid: 22189
# Epoch 0, Loss: 4.685057640075684
# Epoch 100, Loss: 1.9996622800827026
# Epoch 200, Loss: 0.8503756523132324
# Epoch 300, Loss: 0.4496842920780182
# Epoch 400, Loss: 0.27205899357795715
# Best model restored with loss 0.1837
# Processing uid: 22190
# Epoch 0, Loss: 4.43062162399292
# Epoch 100, Loss: 1.8927236795425415
# Epoch 200, Loss: 0.9626154899597168
# Epoch 300, Loss: 0.47397366166114807
# Epoch 400, Loss: 0.2757475674152374
# Best model restored with loss 0.1830
# Processing uid: 22191
# Epoch 0, Loss: 4.13665246963501
# Epoch 100, Loss: 1.591084361076355
# Epoch 200, Loss: 1.3765029907226562
# Epoch 300, Loss: 1.2501938343048096
# Epoch 400, Loss: 1.132686734199524
# Best model restored with loss 1.0089
# Processing uid: 22192
# Epoch 0, Loss: 4.984872341156006
# Epoch 100, Loss: 2.827853202819824
# Epoch 200, Loss: 2.2622339725494385
# Epoch 300, Loss: 1.7972724437713623
# Epoch 400, Loss: 1.4545836448669434
# Best model restored with loss 1.2155
# Processing uid: 22193
# Epoch 0, Loss: 4.907071590423584
# Epoch 100, Loss: 2.964163303375244
# Epoch 200, Loss: 2.0429351329803467
# Epoch 300, Loss: 1.431824803352356
# Epoch 400, Loss: 1.0710428953170776
# Best model restored with loss 0.8477
# Processing uid: 22194
# Epoch 0, Loss: 4.668118476867676
# Epoch 100, Loss: 2.4442222118377686
# Epoch 200, Loss: 1.3407338857650757
# Epoch 300, Loss: 0.7846401929855347
# Epoch 400, Loss: 0.5144226551055908
# Best model restored with loss 0.3702
# Processing uid: 22195
# Epoch 0, Loss: 4.966777324676514
# Epoch 100, Loss: 2.6744163036346436
# Epoch 200, Loss: 1.6140340566635132
# Epoch 300, Loss: 0.9962249994277954
# Epoch 400, Loss: 0.6620375514030457
# Best model restored with loss 0.4780
# Processing uid: 22196
# Epoch 0, Loss: 4.020942687988281
# Epoch 100, Loss: 1.9820973873138428
# Epoch 200, Loss: 1.5830549001693726
# Epoch 300, Loss: 1.2496286630630493
# Epoch 400, Loss: 1.0110913515090942
# Best model restored with loss 0.8469
# Processing uid: 22197
# Epoch 0, Loss: 4.208629131317139
# Epoch 100, Loss: 2.1617043018341064
# Epoch 200, Loss: 1.5924102067947388
# Epoch 300, Loss: 1.1410938501358032
# Epoch 400, Loss: 0.8599194288253784
# Best model restored with loss 0.6918
# Processing uid: 22198
# Epoch 0, Loss: 4.686244010925293
# Epoch 100, Loss: 2.5025103092193604
# Epoch 200, Loss: 1.5888416767120361
# Epoch 300, Loss: 1.0229398012161255
# Epoch 400, Loss: 0.7101581692695618
# Best model restored with loss 0.5352
# Processing uid: 22199
# Processing uid: 22200
# Epoch 0, Loss: 4.618309497833252
# Epoch 100, Loss: 2.407426357269287
# Epoch 200, Loss: 2.166860818862915
# Epoch 300, Loss: 1.9652011394500732
# Epoch 400, Loss: 1.7940750122070312
# Best model restored with loss 1.6484
# Processing uid: 22201
# Epoch 0, Loss: 3.9913084506988525
# Epoch 100, Loss: 1.6346993446350098
# Epoch 200, Loss: 1.491896390914917
# Epoch 300, Loss: 1.279427170753479
# Epoch 400, Loss: 1.0531550645828247
# Best model restored with loss 0.8781
# Processing uid: 22202
# Epoch 0, Loss: 4.365657806396484
# Epoch 100, Loss: 2.219735622406006
# Epoch 200, Loss: 1.8417071104049683
# Epoch 300, Loss: 1.5250561237335205
# Epoch 400, Loss: 1.2991478443145752
# Best model restored with loss 1.1483
# Processing uid: 22203
# Processing uid: 22204
# Epoch 0, Loss: 4.570275783538818
# Epoch 100, Loss: 2.081366777420044
# Epoch 200, Loss: 0.9236298203468323
# Epoch 300, Loss: 0.552992582321167
# Epoch 400, Loss: 0.3926330506801605
# Best model restored with loss 0.3050
# Processing uid: 22205
# Epoch 0, Loss: 4.805547714233398
# Epoch 100, Loss: 2.4688336849212646
# Epoch 200, Loss: 1.5752428770065308
# Epoch 300, Loss: 1.0237109661102295
# Epoch 400, Loss: 0.7070602178573608
# Best model restored with loss 0.5237
# Processing uid: 22206
# Epoch 0, Loss: 5.011835098266602
# Epoch 100, Loss: 2.9961435794830322
# Epoch 200, Loss: 1.770283818244934
# Epoch 300, Loss: 1.098028302192688
# Epoch 400, Loss: 0.758582592010498
# Best model restored with loss 0.5695
# Processing uid: 22207
# Processing uid: 22208
# Epoch 0, Loss: 4.119242191314697
# Epoch 100, Loss: 2.398589611053467
# Epoch 200, Loss: 2.0594677925109863
# Epoch 300, Loss: 1.773518443107605
# Epoch 400, Loss: 1.5661497116088867
# Best model restored with loss 1.4145
# Processing uid: 22209
# Epoch 0, Loss: 4.891561508178711
# Epoch 100, Loss: 2.628603458404541
# Epoch 200, Loss: 1.563063621520996
# Epoch 300, Loss: 1.0657683610916138
# Epoch 400, Loss: 0.7974287867546082
# Best model restored with loss 0.6368
# Processing uid: 22210
# Epoch 0, Loss: 4.390172958374023
# Epoch 100, Loss: 1.6765944957733154
# Epoch 200, Loss: 1.2188857793807983
# Epoch 300, Loss: 0.7366786003112793
# Epoch 400, Loss: 0.4549311101436615
# Best model restored with loss 0.3085
# Processing uid: 22211
# Processing uid: 22212
# Epoch 0, Loss: 5.059924125671387
# Epoch 100, Loss: 3.258125066757202
# Epoch 200, Loss: 2.4938013553619385
# Epoch 300, Loss: 1.8571321964263916
# Epoch 400, Loss: 1.4257627725601196
# Best model restored with loss 1.1478
# Processing uid: 22213
# Processing uid: 22214
# Processing uid: 22215
# Epoch 0, Loss: 4.41911506652832
# Epoch 100, Loss: 1.764868974685669
# Epoch 200, Loss: 1.0803593397140503
# Epoch 300, Loss: 0.6361692547798157
# Epoch 400, Loss: 0.4168378412723541
# Best model restored with loss 0.3023
# Processing uid: 22216
# Processing uid: 22217
# Epoch 0, Loss: 4.896644115447998
# Epoch 100, Loss: 3.018805980682373
# Epoch 200, Loss: 1.9161616563796997
# Epoch 300, Loss: 1.1796488761901855
# Epoch 400, Loss: 0.7748592495918274
# Best model restored with loss 0.5565
# Processing uid: 22218
# Epoch 0, Loss: 3.7962751388549805
# Epoch 100, Loss: 1.5403169393539429
# Epoch 200, Loss: 1.1711736917495728
# Epoch 300, Loss: 0.8625132441520691
# Epoch 400, Loss: 0.6394094824790955
# Best model restored with loss 0.5015
# Processing uid: 22219
# Epoch 0, Loss: 4.821589469909668
# Epoch 100, Loss: 2.443646192550659
# Epoch 200, Loss: 2.253908157348633
# Epoch 300, Loss: 2.0509228706359863
# Epoch 400, Loss: 1.8716918230056763
# Best model restored with loss 1.7081
# Processing uid: 22220
# Epoch 0, Loss: 4.221240997314453
# Epoch 100, Loss: 2.184616804122925
# Epoch 200, Loss: 1.4440053701400757
# Epoch 300, Loss: 0.8567942380905151
# Epoch 400, Loss: 0.5263242721557617
# Best model restored with loss 0.3558
# Processing uid: 22221
# Epoch 0, Loss: 4.664880275726318
# Epoch 100, Loss: 2.3287510871887207
# Epoch 200, Loss: 1.3919702768325806
# Epoch 300, Loss: 0.860001266002655
# Epoch 400, Loss: 0.5914456248283386
# Best model restored with loss 0.4437
# Processing uid: 22222
# Epoch 0, Loss: 5.005570888519287
# Epoch 100, Loss: 2.7927043437957764
# Epoch 200, Loss: 1.5532857179641724
# Epoch 300, Loss: 0.9878714680671692
# Epoch 400, Loss: 0.7075667977333069
# Best model restored with loss 0.5428
# Processing uid: 22223
# Epoch 0, Loss: 4.946189880371094
# Epoch 100, Loss: 3.180410861968994
# Epoch 200, Loss: 2.5951032638549805
# Epoch 300, Loss: 2.0914878845214844
# Epoch 400, Loss: 1.7151925563812256
# Best model restored with loss 1.4392
# Processing uid: 22224
# Epoch 0, Loss: 4.558867454528809
# Epoch 100, Loss: 2.4332828521728516
# Epoch 200, Loss: 1.0575343370437622
# Epoch 300, Loss: 0.5286911725997925
# Epoch 400, Loss: 0.3248817026615143
# Best model restored with loss 0.2247
# Processing uid: 22225
# Epoch 0, Loss: 4.727975845336914
# Epoch 100, Loss: 2.541517496109009
# Epoch 200, Loss: 2.2061352729797363
# Epoch 300, Loss: 1.7888991832733154
# Epoch 400, Loss: 1.4168237447738647
# Best model restored with loss 1.1318
# Processing uid: 22226
# Epoch 0, Loss: 5.099562168121338
# Epoch 100, Loss: 2.7932496070861816
# Epoch 200, Loss: 2.2247235774993896
# Epoch 300, Loss: 1.7676345109939575
# Epoch 400, Loss: 1.433798909187317
# Best model restored with loss 1.2095
# Processing uid: 22227
# Processing uid: 22228
# Processing uid: 22229
# Epoch 0, Loss: 4.635407447814941
# Epoch 100, Loss: 2.5863447189331055
# Epoch 200, Loss: 1.5943107604980469
# Epoch 300, Loss: 1.0377362966537476
# Epoch 400, Loss: 0.7547870874404907
# Best model restored with loss 0.5964
# Processing uid: 22230
# Epoch 0, Loss: 4.614412307739258
# Epoch 100, Loss: 2.1480207443237305
# Epoch 200, Loss: 1.6130545139312744
# Epoch 300, Loss: 1.1855952739715576
# Epoch 400, Loss: 0.883262574672699
# Best model restored with loss 0.6855
# Processing uid: 22231
# Epoch 0, Loss: 4.658210754394531
# Epoch 100, Loss: 2.6111273765563965
# Epoch 200, Loss: 1.8464609384536743
# Epoch 300, Loss: 1.2882040739059448
# Epoch 400, Loss: 0.9594537615776062
# Best model restored with loss 0.7632
# Processing uid: 22232
# Epoch 0, Loss: 4.6820878982543945
# Epoch 100, Loss: 2.228161334991455
# Epoch 200, Loss: 1.813981056213379
# Epoch 300, Loss: 1.4201922416687012
# Epoch 400, Loss: 1.0964595079421997
# Best model restored with loss 0.8552
# Processing uid: 22233
# Epoch 0, Loss: 4.107794761657715
# Epoch 100, Loss: 2.3779802322387695
# Epoch 200, Loss: 1.678928256034851
# Epoch 300, Loss: 1.1679692268371582
# Epoch 400, Loss: 0.8687548041343689
# Best model restored with loss 0.6877
# Processing uid: 22234
# Epoch 0, Loss: 4.941073417663574
# Epoch 100, Loss: 2.9122931957244873
# Epoch 200, Loss: 1.680372714996338
# Epoch 300, Loss: 1.082611322402954
# Epoch 400, Loss: 0.7789233922958374
# Best model restored with loss 0.6026
# Processing uid: 22235
# Epoch 0, Loss: 5.000291347503662
# Epoch 100, Loss: 2.688326358795166
# Epoch 200, Loss: 1.7485562562942505
# Epoch 300, Loss: 1.1319788694381714
# Epoch 400, Loss: 0.8080937266349792
# Best model restored with loss 0.6282
# Processing uid: 22236
# Epoch 0, Loss: 5.041660308837891
# Epoch 100, Loss: 2.7054708003997803
# Epoch 200, Loss: 1.5436420440673828
# Epoch 300, Loss: 1.012977123260498
# Epoch 400, Loss: 0.7457699775695801
# Best model restored with loss 0.5877
# Processing uid: 22237
# Epoch 0, Loss: 4.97712516784668
# Epoch 100, Loss: 2.629962921142578
# Epoch 200, Loss: 1.3261046409606934
# Epoch 300, Loss: 0.803195059299469
# Epoch 400, Loss: 0.5540462732315063
# Best model restored with loss 0.4133
# Processing uid: 22238
# Epoch 0, Loss: 4.153444290161133
# Epoch 100, Loss: 1.6971105337142944
# Epoch 200, Loss: 0.7559551000595093
# Epoch 300, Loss: 0.4036608934402466
# Epoch 400, Loss: 0.2560518682003021
# Best model restored with loss 0.1806
# Processing uid: 22239
# Epoch 0, Loss: 4.829250335693359
# Epoch 100, Loss: 3.078681468963623
# Epoch 200, Loss: 2.341020107269287
# Epoch 300, Loss: 1.8172284364700317
# Epoch 400, Loss: 1.4762425422668457
# Best model restored with loss 1.2399
# Processing uid: 22240
# Processing uid: 22241
# Epoch 0, Loss: 4.234679222106934
# Epoch 100, Loss: 2.797694206237793
# Epoch 200, Loss: 2.2133703231811523
# Epoch 300, Loss: 1.7149932384490967
# Epoch 400, Loss: 1.3836413621902466
# Best model restored with loss 1.1600
# Processing uid: 22242
# Epoch 0, Loss: 4.243664741516113
# Epoch 100, Loss: 2.262373447418213
# Epoch 200, Loss: 1.2879256010055542
# Epoch 300, Loss: 0.7347845435142517
# Epoch 400, Loss: 0.46287527680397034
# Best model restored with loss 0.3188
# Processing uid: 22243
# Epoch 0, Loss: 4.757018089294434
# Epoch 100, Loss: 2.158942937850952
# Epoch 200, Loss: 1.7665947675704956
# Epoch 300, Loss: 1.3435310125350952
# Epoch 400, Loss: 1.034661889076233
# Best model restored with loss 0.8411
# Processing uid: 22244
# Epoch 0, Loss: 4.450075626373291
# Epoch 100, Loss: 2.6118226051330566
# Epoch 200, Loss: 1.6031054258346558
# Epoch 300, Loss: 1.048740267753601
# Epoch 400, Loss: 0.7720310688018799
# Best model restored with loss 0.6135
# Processing uid: 22245
# Epoch 0, Loss: 4.601372241973877
# Epoch 100, Loss: 2.411498785018921
# Epoch 200, Loss: 1.7976301908493042
# Epoch 300, Loss: 1.312712550163269
# Epoch 400, Loss: 0.9806066155433655
# Best model restored with loss 0.7695
# Processing uid: 22246
# Epoch 0, Loss: 3.8059182167053223
# ...
# Processing uid: 5909
# Epoch 0, Loss: 5.222697734832764
# Epoch 100, Loss: 2.9804744720458984
# Epoch 200, Loss: 2.159607172012329
# Epoch 300, Loss: 1.6271089315414429
# Epoch 400, Loss: 1.3016608953475952
# Best model restored with loss 1.1033
# Processing uid: 5910
# Processing uid: 5911
# Epoch 0, Loss: 4.666637420654297
# Epoch 100, Loss: 1.7840473651885986
# Epoch 200, Loss: 0.7519729137420654
# Epoch 300, Loss: 0.44684797525405884
# Epoch 400, Loss: 0.31742846965789795
# Best model restored with loss 0.2532
# Processing uid: 5912
# Processing uid: 5913
# Epoch 0, Loss: 5.1153974533081055
# Epoch 100, Loss: 2.670430898666382
# Epoch 200, Loss: 1.3244825601577759
# Epoch 300, Loss: 0.7786658406257629
# Epoch 400, Loss: 0.5267648696899414
# Best model restored with loss 0.3905
# Processing uid: 5914
# Epoch 0, Loss: 4.492051124572754
# Epoch 100, Loss: 2.270913600921631
# Epoch 200, Loss: 1.1431074142456055
# Epoch 300, Loss: 0.6356940865516663
# Epoch 400, Loss: 0.41462498903274536
# Best model restored with loss 0.3069
# Processing uid: 5915
# Processing uid: 5916
# Processing uid: 5917
# Processing uid: 5918
# Processing uid: 5919
# Epoch 0, Loss: 4.464843273162842
# Epoch 100, Loss: 2.3410263061523438
# Epoch 200, Loss: 1.0203559398651123
# Epoch 300, Loss: 0.5492449402809143
# Epoch 400, Loss: 0.36549004912376404
# Best model restored with loss 0.2732
# Processing uid: 5920
# Epoch 0, Loss: 4.290048599243164
# Epoch 100, Loss: 1.997281551361084
# Epoch 200, Loss: 1.8084018230438232
# Epoch 300, Loss: 1.5802563428878784
# Epoch 400, Loss: 1.3662716150283813
# Best model restored with loss 1.1879
# Processing uid: 5921
# Epoch 0, Loss: 4.468334674835205
# Epoch 100, Loss: 1.6110970973968506
# Epoch 200, Loss: 1.3936463594436646
# Epoch 300, Loss: 1.158926248550415
# Epoch 400, Loss: 0.9615160822868347
# Best model restored with loss 0.8097
# Processing uid: 5922
# Epoch 0, Loss: 4.5078582763671875
# Epoch 100, Loss: 2.0675673484802246
# Epoch 200, Loss: 1.8633978366851807
# Epoch 300, Loss: 1.6672799587249756
# Epoch 400, Loss: 1.4770898818969727
# Best model restored with loss 1.3063
# Processing uid: 5923
# Epoch 0, Loss: 4.756326675415039
# Epoch 100, Loss: 1.985497236251831
# Epoch 200, Loss: 1.7572625875473022
# Epoch 300, Loss: 1.5526944398880005
# Epoch 400, Loss: 1.384313941001892
# Best model restored with loss 1.2576
# Processing uid: 5924
# Epoch 0, Loss: 4.683835983276367
# Epoch 100, Loss: 2.0181403160095215
# Epoch 200, Loss: 0.9037191867828369
# Epoch 300, Loss: 0.5247851014137268
# Epoch 400, Loss: 0.3549875319004059
# Best model restored with loss 0.2622
# Processing uid: 5925
# Epoch 0, Loss: 4.601912975311279
# Epoch 100, Loss: 2.363069534301758
# Epoch 200, Loss: 0.9480302929878235
# Epoch 300, Loss: 0.4523165822029114
# Epoch 400, Loss: 0.2695654332637787
# Best model restored with loss 0.1839
# Processing uid: 5926
# Epoch 0, Loss: 4.015133857727051
# Epoch 100, Loss: 1.759331226348877
# Epoch 200, Loss: 0.9665672183036804
# Epoch 300, Loss: 0.5350945591926575
# Epoch 400, Loss: 0.33949923515319824
# Best model restored with loss 0.2390
# Processing uid: 5927
# Epoch 0, Loss: 4.175979137420654
# Epoch 100, Loss: 1.9561164379119873
# Epoch 200, Loss: 1.5948152542114258
# Epoch 300, Loss: 1.244289517402649
# Epoch 400, Loss: 1.0019959211349487
# Best model restored with loss 0.8322
# Processing uid: 5928
# Processing uid: 5929
# Epoch 0, Loss: 4.413201808929443
# Epoch 100, Loss: 2.2491750717163086
# Epoch 200, Loss: 1.5612564086914062
# Epoch 300, Loss: 1.2185684442520142
# Epoch 400, Loss: 1.0285996198654175
# Best model restored with loss 0.9079
# Processing uid: 5930
# Processing uid: 5931
# Processing uid: 5932
# Epoch 0, Loss: 4.4197001457214355
# Epoch 100, Loss: 2.1318767070770264
# Epoch 200, Loss: 1.893164038658142
# Epoch 300, Loss: 1.661008596420288
# Epoch 400, Loss: 1.4433870315551758
# Best model restored with loss 1.2510
# Processing uid: 5933
# Epoch 0, Loss: 3.701547145843506
# Epoch 100, Loss: 1.4793003797531128
# Epoch 200, Loss: 0.9104352593421936
# Epoch 300, Loss: 0.5595811605453491
# Epoch 400, Loss: 0.37086108326911926
# Best model restored with loss 0.2661
# Processing uid: 5934
# Epoch 0, Loss: 4.774171352386475
# Epoch 100, Loss: 2.6944055557250977
# Epoch 200, Loss: 2.1879732608795166
# Epoch 300, Loss: 1.8284955024719238
# Epoch 400, Loss: 1.5577549934387207
# Best model restored with loss 1.3595
# Processing uid: 5935
# Epoch 0, Loss: 4.686924457550049
# Epoch 100, Loss: 2.5110034942626953
# Epoch 200, Loss: 2.2450525760650635
# Epoch 300, Loss: 2.0370514392852783
# Epoch 400, Loss: 1.8596855401992798
# Best model restored with loss 1.7053
# Processing uid: 5936
# Processing uid: 5937
# Epoch 0, Loss: 3.8716447353363037
# Epoch 100, Loss: 1.697465419769287
# Epoch 200, Loss: 1.4165339469909668
# Epoch 300, Loss: 1.158233642578125
# Epoch 400, Loss: 0.9376824498176575
# Best model restored with loss 0.7809
# Processing uid: 5938
# Epoch 0, Loss: 4.125323295593262
# Epoch 100, Loss: 2.016737937927246
# Epoch 200, Loss: 1.675950050354004
# Epoch 300, Loss: 1.3180521726608276
# Epoch 400, Loss: 1.0116840600967407
# Best model restored with loss 0.7981
# Processing uid: 5939
# Processing uid: 5940
# Processing uid: 5941
# Processing uid: 5942
# Epoch 0, Loss: 4.764646053314209
# Epoch 100, Loss: 2.6852915287017822
# Epoch 200, Loss: 1.8552119731903076
# Epoch 300, Loss: 1.453829288482666
# Epoch 400, Loss: 1.2367146015167236
# Best model restored with loss 1.1119
# Processing uid: 5943
# Epoch 0, Loss: 4.206477642059326
# Epoch 100, Loss: 2.195850372314453
# Epoch 200, Loss: 1.3594810962677002
# Epoch 300, Loss: 0.8368709683418274
# Epoch 400, Loss: 0.5688217878341675
# Best model restored with loss 0.4186
# Processing uid: 5944
# Epoch 0, Loss: 5.250983715057373
# Epoch 100, Loss: 3.1766791343688965
# Epoch 200, Loss: 2.01847505569458
# Epoch 300, Loss: 1.3734720945358276
# Epoch 400, Loss: 1.0344964265823364
# Best model restored with loss 0.8392
# Processing uid: 5945
# Epoch 0, Loss: 4.538304805755615
# Epoch 100, Loss: 2.7499353885650635
# Epoch 200, Loss: 2.2583913803100586
# Epoch 300, Loss: 1.8881784677505493
# Epoch 400, Loss: 1.6334993839263916
# Best model restored with loss 1.4631
# Processing uid: 5946
# Epoch 0, Loss: 4.754291534423828
# Epoch 100, Loss: 2.52951979637146
# Epoch 200, Loss: 2.008484363555908
# Epoch 300, Loss: 1.607630968093872
# Epoch 400, Loss: 1.3206522464752197
# Best model restored with loss 1.1245
# Processing uid: 5947
# Epoch 0, Loss: 4.579799175262451
# Epoch 100, Loss: 2.179868221282959
# Epoch 200, Loss: 0.9212461113929749
# Epoch 300, Loss: 0.5097183585166931
# Epoch 400, Loss: 0.33884963393211365
# Best model restored with loss 0.2456
# Processing uid: 5948
# Epoch 0, Loss: 4.924070358276367
# Epoch 100, Loss: 3.1990675926208496
# Epoch 200, Loss: 2.55631685256958
# Epoch 300, Loss: 2.092827081680298
# Epoch 400, Loss: 1.7707237005233765
# Best model restored with loss 1.5504
# Processing uid: 5949
# Processing uid: 5950
# Processing uid: 5951
# Epoch 0, Loss: 4.485258102416992
# Epoch 100, Loss: 1.8223953247070312
# Epoch 200, Loss: 1.48093581199646
# Epoch 300, Loss: 1.088828682899475
# Epoch 400, Loss: 0.7996700406074524
# Best model restored with loss 0.6250
# Processing uid: 5952
# Epoch 0, Loss: 3.9428091049194336
# Epoch 100, Loss: 1.565455675125122
# Epoch 200, Loss: 1.3370424509048462
# Epoch 300, Loss: 1.1162536144256592
# Epoch 400, Loss: 0.935572624206543
# Best model restored with loss 0.7962
# Processing uid: 5953
# Epoch 0, Loss: 4.717527389526367
# Epoch 100, Loss: 2.2468364238739014
# Epoch 200, Loss: 1.976952075958252
# Epoch 300, Loss: 1.7658300399780273
# Epoch 400, Loss: 1.5809576511383057
# Best model restored with loss 1.4259
# Processing uid: 5954
# Epoch 0, Loss: 4.340931415557861
# Epoch 100, Loss: 2.527683973312378
# Epoch 200, Loss: 1.993923544883728
# Epoch 300, Loss: 1.4901673793792725
# Epoch 400, Loss: 1.1448512077331543
# Best model restored with loss 0.9257
# Processing uid: 5955
# Processing uid: 5956
# Epoch 0, Loss: 4.206876754760742
# Epoch 100, Loss: 2.229341506958008
# Epoch 200, Loss: 1.9579623937606812
# Epoch 300, Loss: 1.7122039794921875
# Epoch 400, Loss: 1.48381769657135
# Best model restored with loss 1.2996
# Processing uid: 5957
# Processing uid: 5958
# Processing uid: 5959
# Processing uid: 5960
# Epoch 0, Loss: 4.543939590454102
# Epoch 100, Loss: 2.639176368713379
# Epoch 200, Loss: 2.211954116821289
# Epoch 300, Loss: 1.8765226602554321
# Epoch 400, Loss: 1.6249921321868896
# Best model restored with loss 1.4509
# Processing uid: 5961
# Processing uid: 5962
# Epoch 0, Loss: 4.685697555541992
# Epoch 100, Loss: 2.876424551010132
# Epoch 200, Loss: 1.7189041376113892
# Epoch 300, Loss: 1.103574514389038
# Epoch 400, Loss: 0.7816554307937622
# Best model restored with loss 0.5872
# Processing uid: 5963
# Epoch 0, Loss: 5.293865203857422
# Epoch 100, Loss: 2.4738385677337646
# Epoch 200, Loss: 2.192854166030884
# Epoch 300, Loss: 1.929221749305725
# Epoch 400, Loss: 1.7147756814956665
# Best model restored with loss 1.5432
# Processing uid: 5964
# Epoch 0, Loss: 4.961727142333984
# Epoch 100, Loss: 3.049032688140869
# Epoch 200, Loss: 1.943853735923767
# Epoch 300, Loss: 1.2896959781646729
# Epoch 400, Loss: 0.938386857509613
# Best model restored with loss 0.7343
# Processing uid: 5965
# Epoch 0, Loss: 5.290369033813477
# Epoch 100, Loss: 3.339782238006592
# Epoch 200, Loss: 2.334364175796509
# Epoch 300, Loss: 1.6388553380966187
# Epoch 400, Loss: 1.2181230783462524
# Best model restored with loss 0.9497
# Processing uid: 5966
# Epoch 0, Loss: 4.299174785614014
# Epoch 100, Loss: 2.5791561603546143
# Epoch 200, Loss: 2.3476085662841797
# Epoch 300, Loss: 2.106926679611206
# Epoch 400, Loss: 1.904144287109375
# Best model restored with loss 1.7400
# Processing uid: 5967
# Epoch 0, Loss: 4.675285816192627
# Epoch 100, Loss: 2.4584124088287354
# Epoch 200, Loss: 2.195728302001953
# Epoch 300, Loss: 1.9252777099609375
# Epoch 400, Loss: 1.6772708892822266
# Best model restored with loss 1.4835
# Processing uid: 5968
# Processing uid: 5969
# Epoch 0, Loss: 4.845107555389404
# Epoch 100, Loss: 2.535468339920044
# Epoch 200, Loss: 2.074401378631592
# Epoch 300, Loss: 1.6883724927902222
# Epoch 400, Loss: 1.381203055381775
# Best model restored with loss 1.1615
# Processing uid: 5970
# Epoch 0, Loss: 4.774200439453125
# Epoch 100, Loss: 2.3424582481384277
# Epoch 200, Loss: 1.7244561910629272
# Epoch 300, Loss: 1.2273647785186768
# Epoch 400, Loss: 0.9375404119491577
# Best model restored with loss 0.7703
# Processing uid: 5971
# Epoch 0, Loss: 4.462945461273193
# Epoch 100, Loss: 2.2074928283691406
# Epoch 200, Loss: 1.759492039680481
# Epoch 300, Loss: 1.3815855979919434
# Epoch 400, Loss: 1.0975292921066284
# Best model restored with loss 0.8981
# Processing uid: 5972
# Processing uid: 5973
# Epoch 0, Loss: 4.709860801696777
# Epoch 100, Loss: 2.6193125247955322
# Epoch 200, Loss: 1.8480256795883179
# Epoch 300, Loss: 1.2331969738006592
# Epoch 400, Loss: 0.8471437096595764
# Best model restored with loss 0.6268
# Processing uid: 5974
# Epoch 0, Loss: 5.051342487335205
# Epoch 100, Loss: 2.4498701095581055
# Epoch 200, Loss: 1.9745454788208008
# Epoch 300, Loss: 1.5750545263290405
# Epoch 400, Loss: 1.2846866846084595
# Best model restored with loss 1.0859
# Processing uid: 5975
# Epoch 0, Loss: 4.424956798553467
# Epoch 100, Loss: 2.316096067428589
# Epoch 200, Loss: 1.9636788368225098
# Epoch 300, Loss: 1.5825601816177368
# Epoch 400, Loss: 1.2474004030227661
# Best model restored with loss 1.0033
# Processing uid: 5976
# Epoch 0, Loss: 4.988211154937744
# Epoch 100, Loss: 2.7454617023468018
# Epoch 200, Loss: 2.3024837970733643
# Epoch 300, Loss: 1.8897980451583862
# Epoch 400, Loss: 1.610997200012207
# Best model restored with loss 1.4206
# Processing uid: 5977
# Epoch 0, Loss: 4.73993444442749
# Epoch 100, Loss: 2.6722564697265625
# Epoch 200, Loss: 2.1091644763946533
# Epoch 300, Loss: 1.630704402923584
# Epoch 400, Loss: 1.3145049810409546
# Best model restored with loss 1.1109
# Processing uid: 5978
# Epoch 0, Loss: 4.958227157592773
# Epoch 100, Loss: 3.4088289737701416
# Epoch 200, Loss: 2.6460907459259033
# Epoch 300, Loss: 2.135540008544922
# Epoch 400, Loss: 1.8247967958450317
# Best model restored with loss 1.6214
# Processing uid: 5979
# Epoch 0, Loss: 4.699421405792236
# Epoch 100, Loss: 1.819722294807434
# Epoch 200, Loss: 1.7173432111740112
# Epoch 300, Loss: 1.5885021686553955
# Epoch 400, Loss: 1.465935468673706
# Best model restored with loss 1.3496
# Processing uid: 5980
# Epoch 0, Loss: 4.328551292419434
# Epoch 100, Loss: 2.6354875564575195
# Epoch 200, Loss: 1.895758032798767
# Epoch 300, Loss: 1.383604884147644
# Epoch 400, Loss: 1.0710116624832153
# Best model restored with loss 0.8707
# Processing uid: 5981
# Processing uid: 5982
# Processing uid: 5983
# Epoch 0, Loss: 4.567991733551025
# Epoch 100, Loss: 2.5970726013183594
# Epoch 200, Loss: 1.3563506603240967
# Epoch 300, Loss: 0.771843671798706
# Epoch 400, Loss: 0.49146512150764465
# Best model restored with loss 0.3496
# Processing uid: 5984
# Epoch 0, Loss: 3.683351993560791
# Epoch 100, Loss: 1.3790193796157837
# Epoch 200, Loss: 0.42863139510154724
# Epoch 300, Loss: 0.15315696597099304
# Epoch 400, Loss: 0.07734441757202148
# Best model restored with loss 0.0482
# Processing uid: 5985
# Epoch 0, Loss: 5.235286712646484
# Epoch 100, Loss: 2.9051475524902344
# Epoch 200, Loss: 1.6115336418151855
# Epoch 300, Loss: 1.0232707262039185
# Epoch 400, Loss: 0.7338721752166748
# Best model restored with loss 0.5692
# Processing uid: 5986
# Epoch 0, Loss: 4.641319274902344
# Epoch 100, Loss: 2.3998935222625732
# Epoch 200, Loss: 1.8645102977752686
# Epoch 300, Loss: 1.4309773445129395
# Epoch 400, Loss: 1.1321015357971191
# Best model restored with loss 0.9381
# Processing uid: 5987
# Epoch 0, Loss: 4.627540111541748
# Epoch 100, Loss: 2.000049591064453
# Epoch 200, Loss: 1.8553130626678467
# Epoch 300, Loss: 1.7205339670181274
# Epoch 400, Loss: 1.592051386833191
# Best model restored with loss 1.4717
# Processing uid: 5988
# Processing uid: 5989
# Epoch 0, Loss: 4.3828043937683105
# Epoch 100, Loss: 2.4282712936401367
# Epoch 200, Loss: 1.8946056365966797
# Epoch 300, Loss: 1.4803102016448975
# Epoch 400, Loss: 1.2072681188583374
# Best model restored with loss 1.0244
# Processing uid: 5990
# Epoch 0, Loss: 4.41602087020874
# Epoch 100, Loss: 2.400893211364746
# Epoch 200, Loss: 1.5162595510482788
# Epoch 300, Loss: 1.0385992527008057
# Epoch 400, Loss: 0.7752004861831665
# Best model restored with loss 0.6134
# Processing uid: 5991
# Epoch 0, Loss: 5.229394435882568
# Epoch 100, Loss: 2.2890565395355225
# Epoch 200, Loss: 0.8272174596786499
# Epoch 300, Loss: 0.40852102637290955
# Epoch 400, Loss: 0.2545948326587677
# Best model restored with loss 0.1776
# Processing uid: 5992
# Epoch 0, Loss: 3.8336265087127686
# Epoch 100, Loss: 1.6404812335968018
# Epoch 200, Loss: 1.348071813583374
# Epoch 300, Loss: 1.0885182619094849
# Epoch 400, Loss: 0.8653043508529663
# Best model restored with loss 0.7000
# Processing uid: 5993
# Epoch 0, Loss: 4.1794633865356445
# Epoch 100, Loss: 1.919463872909546
# Epoch 200, Loss: 1.4037309885025024
# Epoch 300, Loss: 1.0440796613693237
# Epoch 400, Loss: 0.7976909875869751
# Best model restored with loss 0.6405
# Processing uid: 5994
# Epoch 0, Loss: 3.738171339035034
# Epoch 100, Loss: 1.7835890054702759
# Epoch 200, Loss: 1.2278339862823486
# Epoch 300, Loss: 0.8662780523300171
# Epoch 400, Loss: 0.6422365307807922
# Best model restored with loss 0.4952
# Processing uid: 5995
# Epoch 0, Loss: 4.8036417961120605
# Epoch 100, Loss: 2.618586540222168
# Epoch 200, Loss: 2.0783300399780273
# Epoch 300, Loss: 1.59482741355896
# Epoch 400, Loss: 1.2591465711593628
# Best model restored with loss 1.0357
# Processing uid: 5996
# Epoch 0, Loss: 4.4197001457214355
# Epoch 100, Loss: 1.7462772130966187
# Epoch 200, Loss: 0.9999677538871765
# Epoch 300, Loss: 0.6508357524871826
# Epoch 400, Loss: 0.4730779230594635
# Best model restored with loss 0.3721
# Processing uid: 5997
# Epoch 0, Loss: 4.458009243011475
# Epoch 100, Loss: 2.292264938354492
# Epoch 200, Loss: 1.3798469305038452
# Epoch 300, Loss: 0.9816257953643799
# Epoch 400, Loss: 0.773158609867096
# Best model restored with loss 0.6550
# Processing uid: 5998
# Epoch 0, Loss: 4.4454450607299805
# Epoch 100, Loss: 2.452117919921875
# Epoch 200, Loss: 1.9591737985610962
# Epoch 300, Loss: 1.566243052482605
# Epoch 400, Loss: 1.2798525094985962
# Best model restored with loss 1.0739
# Processing uid: 5999
# Epoch 0, Loss: 4.864413261413574
# Epoch 100, Loss: 2.2796287536621094
# Epoch 200, Loss: 1.1385767459869385
# Epoch 300, Loss: 0.6991371512413025
# Epoch 400, Loss: 0.5029967427253723
# Best model restored with loss 0.3923
# ファイル保存完了
# 103.22分

# %%
df = pd.read_csv('submit_file_GNN/mukumuku_cityC_humob24.csv')
df.shape
# Out:
# (449308, 5)
